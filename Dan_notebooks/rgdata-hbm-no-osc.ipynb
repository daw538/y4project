# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan

from IPython.display import display

from matplotlib import rc
rc("font", family="serif", size=11)

# %% [markdown]
# First we will read in a file that contains the overall list of all the available datasets, with corresponding star IDs, $\nu_{max}$ and $\sigma_{\nu_{max}}$ values. From this we will take a random selection for our analysis.

# %%
random.seed(81)
output = pd.read_csv('../data/output_1000stars.csv', usecols=range(1,4))
# Select a random number of stars from the file, recording their IDs
IDs = [random.choice(output['ID']) for i in range(5)]
# Create a list of the numax values corresponding to each ID
Numax = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax_err'] for i in range(len(IDs))]

# %% [markdown]
# Using our list of selected stars, we can then pull the respective files containing the induvidual mode frequencies and errors. The different files will contain varying numbers of modes; in order to successfully parse the data through Stan, one must ensure that all the arrays are of the same length. To do this, for every dataset that contains less modes than the most complete dataset, we can produce additional modes based on the average frequency spacing $\left<\Delta\nu\right>$ for each star, ensuring to assign these points with a large uncertainty so that Stan does not use this as restrictive points during the fit (they are essentially ignored).

# %%
modesID = [pd.read_csv('../data/rgbmodes/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0'])
           for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])


dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
    
dnu_avgarr = np.asarray(dnu_avgID)
print(dnu_avgarr)
# Out:
# [4.12690454 3.84969103 6.65091256 6.712071   4.67533959]

# %% [markdown]
# The data for the different stars can be viewed on an Échelle Diagram.

# %%
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
A = 0.06*dnu_avgarr**(-0.88) 
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*10
phi = np.ones([len(IDs)])*1.71

plt.ylabel('Frequency')
plt.xlabel(r'Mod. Freq. Spacing ('+ str(u"%.3f" % dnu_avg) +') $\mu$Hz')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.5)
#plt.savefig('seminar/manyrgbs.pdf')
plt.show()

print(alpha)
# Out:
# [0.00952997 0.0097444  0.0081803  0.00815637 0.00915695]

# %% [markdown]
# With all our required data, we can parse the data into a stan model constructed to perform a hierarchical Bayesian model. Hyperpriors have been introduced on a number of parameters based on values in the Vrard (2014) paper.

# %%
code = '''
data {
    int N; //number of stars
    int M; //number of modes
    real n[N, M];
    real freq[N, M];
    real freq_err[N, M];
    real dnu_guess[N];
}
parameters {
    real dnu[N];
    real nmax[N];
    real<lower=0> epsilon[N];
    real alpha[N];

    real epsA;
    real epsB;
    real alA;
    real alB;

    
}


model {
    real mod[M];
    for (i in 1:N){
        for (j in 1:M){
            mod[j] = (n[i,j] + epsilon[i] + (alpha[i]/2) * (nmax[i] - n[i,j])^2)*dnu[i];
            mod[j] ~ normal(freq[i], freq_err[i]);
        }
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.001);
        epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
    }
    
    //epsilon ~ normal(1.0, 0.8);
    nmax ~ normal(10, 4);
    //alpha ~ lognormal(log(0.015*dnu^(-0.32)), 0.3);
    //A ~ lognormal(log(0.06*dnu^(-0.88)), 0.4);
    
    //epsA ~ normal(0.601, 0.080);
    //epsB ~ normal(0.632, 0.080);
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_443cbbd4d698433de8ab5fa4db81b2c4 NOW.

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr
        }
start = {'dnu': dnu_avgarr,
         'nmax': nmax,
         'epsilon': epsilon,
         'alpha': alpha,
         'epsA': 0.601,
         'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
    }
nchains = 4

fit = sm.sampling(data=stan_data, iter=10000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[1] is 0.0005926355950230371!
# WARNING:pystan:n_eff / iter for parameter dnu[2] is 0.0003473722395600906!
# WARNING:pystan:n_eff / iter for parameter dnu[3] is 0.0006455785250068117!
# WARNING:pystan:n_eff / iter for parameter dnu[4] is 0.00012805174704815157!
# WARNING:pystan:n_eff / iter for parameter dnu[5] is 0.00025170446473716265!
# WARNING:pystan:n_eff / iter for parameter nmax[1] is 0.00010083490657526349!
# WARNING:pystan:n_eff / iter for parameter nmax[2] is 0.0001075935344259938!
# WARNING:pystan:n_eff / iter for parameter nmax[3] is 0.00010174926695785043!
# WARNING:pystan:n_eff / iter for parameter nmax[4] is 0.00010466982921798393!
# WARNING:pystan:n_eff / iter for parameter nmax[5] is 0.00012949560892626396!
# WARNING:pystan:n_eff / iter for parameter epsilon[1] is 0.00027481349513087006!
# WARNING:pystan:n_eff / iter for parameter epsilon[2] is 0.0003789060528051609!
# WARNING:pystan:n_eff / iter for parameter epsilon[3] is 0.00013443869526177005!
# WARNING:pystan:n_eff / iter for parameter epsilon[4] is 0.00012751431170827425!
# WARNING:pystan:n_eff / iter for parameter epsilon[5] is 0.0003349610120132455!
# WARNING:pystan:n_eff / iter for parameter alpha[3] is 0.0001356648398080216!
# WARNING:pystan:n_eff / iter for parameter alpha[4] is 0.0001394400056497412!
# WARNING:pystan:n_eff / iter for parameter alpha[5] is 0.00039690342256112665!
# WARNING:pystan:n_eff / iter for parameter epsA is 0.00010222328045663746!
# WARNING:pystan:n_eff / iter for parameter epsB is 0.0001009428956772918!
# WARNING:pystan:n_eff / iter for parameter alA is 0.00010060432802974974!
# WARNING:pystan:n_eff / iter for parameter alB is 0.00010123958319104958!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.00026777345963337293!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[1] is 1.2483667687179736!
# WARNING:pystan:Rhat for parameter dnu[2] is 1.9244287477700825!
# WARNING:pystan:Rhat for parameter dnu[3] is 1.214814582436297!
# WARNING:pystan:Rhat for parameter dnu[4] is 2.524704379700995!
# WARNING:pystan:Rhat for parameter dnu[5] is 2.4969610977849763!
# WARNING:pystan:Rhat for parameter nmax[1] is 18.505885582763696!
# WARNING:pystan:Rhat for parameter nmax[2] is 4.301777236479278!
# WARNING:pystan:Rhat for parameter nmax[3] is 7.903411602753051!
# WARNING:pystan:Rhat for parameter nmax[4] is 5.789303946812556!
# WARNING:pystan:Rhat for parameter nmax[5] is 2.2416988831002715!
# WARNING:pystan:Rhat for parameter epsilon[1] is 2.4612797906292814!
# WARNING:pystan:Rhat for parameter epsilon[2] is 1.7540924487951994!
# WARNING:pystan:Rhat for parameter epsilon[3] is 2.391714165558827!
# WARNING:pystan:Rhat for parameter epsilon[4] is 2.4516146705322384!
# WARNING:pystan:Rhat for parameter epsilon[5] is 1.9693248322927734!
# WARNING:pystan:Rhat for parameter alpha[2] is 1.1610540184633285!
# WARNING:pystan:Rhat for parameter alpha[3] is 2.3400917003529518!
# WARNING:pystan:Rhat for parameter alpha[4] is 2.883005697413907!
# WARNING:pystan:Rhat for parameter alpha[5] is 1.665261592032961!
# WARNING:pystan:Rhat for parameter epsA is 8.357350082145308!
# WARNING:pystan:Rhat for parameter epsB is 12.252946415920414!
# WARNING:pystan:Rhat for parameter alA is 18.379721171040636!
# WARNING:pystan:Rhat for parameter alB is 12.116966887738823!
# WARNING:pystan:Rhat for parameter lp__ is 1.509972772433202!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:2649 of 20000 iterations ended with a divergence (13.245%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:5 of 20000 iterations saturated the maximum tree depth of 10 (0.025%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.002021558576171306
# WARNING:pystan:Chain 2: E-BFMI = 0.001371091091636922
# WARNING:pystan:Chain 3: E-BFMI = 0.0004057628199310705
# WARNING:pystan:Chain 4: E-BFMI = 0.0009252635390219193
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_443cbbd4d698433de8ab5fa4db81b2c4.
# 4 chains, each with iter=10000; warmup=5000; thin=1;
# post-warmup draws per chain=5000, total post-warmup draws=20000.
#
#              mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]       3.46    0.01   0.04   3.39   3.44   3.46   3.47   3.48     12   1.25
# dnu[2]        2.8    0.06   0.15   2.24   2.82   2.85   2.88   2.88      7   1.92
# dnu[3]       1.26    0.35   1.24   0.39   0.61   0.99   1.52   5.49     13   1.21
# dnu[4]       3.71    1.25    2.0   0.45   2.53   5.13   5.37   5.79      3   2.52
# dnu[5]       3.32    0.29   0.66   1.66   2.65   3.74   3.81   3.88      5    2.5
# nmax[1]      7.31  5.3e-4 7.6e-4   7.31   7.31   7.31   7.31   7.31      2  18.51
# nmax[2]      7.67  9.1e-5 1.3e-4   7.67   7.67   7.67   7.67   7.67      2    4.3
# nmax[3]      9.48  3.1e-4 4.4e-4   9.48   9.48   9.48   9.48   9.48      2    7.9
# nmax[4]     10.91  2.1e-4 3.0e-4  10.91  10.91  10.91  10.91  10.91      2   5.79
# nmax[5]      8.21  7.5e-5 1.2e-4   8.21   8.21   8.21   8.21   8.21      3   2.24
# epsilon[1]   0.66    0.03   0.06    0.6   0.61   0.64   0.69   0.86      5   2.46
# epsilon[2]   0.84    0.26    0.7    0.5   0.53   0.62   0.75   3.38      8   1.75
# epsilon[3]   73.4   29.95  49.11   0.72  31.52  54.48  95.44 153.77      3   2.39
# epsilon[4]  34.48    35.1  56.05   0.68   1.71   2.36  17.26 152.42      3   2.45
# epsilon[5]   3.44    1.47    3.8   0.84   1.04   1.27   6.03  15.61      7   1.97
# alpha[1]   1.6e-5  2.5e-7 2.1e-6 1.2e-5 1.4e-5 1.6e-5 1.7e-5 2.0e-5     67   1.07
# alpha[2]   1.9e-5  5.9e-7 2.8e-6 1.4e-5 1.7e-5 1.9e-5 2.1e-5 2.5e-5     23   1.16
# alpha[3]   8.9e-5  5.1e-5 8.5e-5 3.5e-6 2.8e-5 6.2e-5 7.9e-5 2.7e-4      3   2.34
# alpha[4]   7.5e-5  7.1e-5 1.2e-4 7.8e-6 9.7e-6 1.1e-5 3.4e-5 3.7e-4      3   2.88
# alpha[5]   1.5e-5  2.6e-6 7.3e-6 9.0e-6 1.1e-5 1.2e-5 1.8e-5 3.8e-5      8   1.67
# epsA          0.6  3.0e-4 4.3e-4    0.6    0.6    0.6    0.6    0.6      2   8.36
# epsB         0.63  2.8e-4 4.0e-4   0.63   0.63   0.63   0.63   0.63      2  12.25
# alA        9.7e-3  2.4e-3 3.3e-3 5.7e-3 6.5e-3 9.7e-3   0.01   0.01      2  18.38
# alB          0.32  2.1e-4 3.0e-4   0.32   0.32   0.32   0.32   0.32      2  12.12
# lp__       -4.1e7   3.0e6  7.0e6 -6.1e7 -4.3e7 -4.2e7 -3.6e7 -3.1e7      5   1.51
#
# Samples were drawn using NUTS at Mon Jan 28 17:33:06 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
'''import corner
data = np.vstack([fit['epsilon'], fit['k'], fit['dnu'], fit['nmax'],
                  fit['a'], fit['omega'], fit['phi'], fit['tau']]).T
corner.corner(data, labels=[r'$\epsilon$', r'$k$',r'$\Delta\nu$',r'$n_{max}$',
                            r'$A$', r'$\omega$', r'$\phi$', r'$\tau$'])
              #, truths=[1.436, 0.07, 0.3, 2, 0])
plt.show()'''
# Out:
# "import corner\ndata = np.vstack([fit['epsilon'], fit['k'], fit['dnu'], fit['nmax'],\n                  fit['a'], fit['omega'], fit['phi'], fit['tau']]).T\ncorner.corner(data, labels=[r'$\\epsilon$', r'$k$',r'$\\Delta\nu$',r'$n_{max}$',\n                            r'$A$', r'$\\omega$', r'$\\phi$', r'$\tau$'])\n              #, truths=[1.436, 0.07, 0.3, 2, 0])\nplt.show()"

# %%
'''
#n = np.arange(12,30,1)

plt.figure(4)
plt.scatter(modes['f0'] % dnu_avg, modes['f0'], c='k', marker='x', label=r'$l=$'+str(0))
plt.errorbar(modes['f0'] % dnu_avg, modes['f0'], xerr=modes['f0_err'], zorder=0, fmt="none", label="none",
             c='k', capsize=2, markersize=4, elinewidth=1)

#g = model(n, fit['dnu'].mean(), fit['nmax'].mean(), fit['epsilon'].mean(), fit['k'].mean(),
#          fit['A'].mean(), np.median(fit['omega']), fit['phi'].mean(), fit['tau'].mean())
g2 = model(n, fit['dnu'].mean(), fit['nmax'].mean(), fit['epsilon'].mean(), fit['k'].mean(),
          fit['a'].mean(), np.median(fit['omega']), fit['phi'].mean(), fit['tau'].mean())
#plt.plot(f % dnu_avg, f, ':', label='Guess')
#plt.plot(g % fit['dnu'].mean(), g, label='Fit')
plt.plot(g2 % fit['dnu'].mean(), g2, label='Fit_2D')
#plt.plot(g % dnu, g, label='Fit')

plt.ylabel('Frequency')
plt.xlabel(f'Mod. Freq. Spacing ('+ str(u"%.3f" % dnu_avg) +') $\mu$Hz')
#plt.xlim(58,68)
plt.legend()
plt.show()
'''

# %%
# %matplotlib inline
def model(n,dnu,nmax,eps,alpha):
    s = (n + eps + ((alpha/2)*(nmax-n)**2))*dnu
    return s


fig = plt.figure(1, figsize=(12,4))
ax  = fig.add_subplot(111)
ax.set_position([0.1,0.1,0.6,0.85])

import itertools
colours1 = itertools.cycle(('r', 'orange', 'limegreen', 'teal', 'lightblue', 'indigo'))
colours2 = itertools.cycle(('r', 'orange', 'limegreen', 'teal', 'lightblue', 'indigo'))
    
for i in np.arange(0,len(IDs),1):
    ax.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label=r'ID = '+str(IDs[i]), c=next(colours1))
   
    g2 = model(arr_n[i],
           np.mean(fit['dnu'], axis=0)[i],
           np.mean(fit['nmax'], axis=0)[i],
           np.mean(fit['epsilon'], axis=0)[i],
           np.mean(fit['alpha'], axis=0)[i])
    
    ax.plot(g2 % np.mean(fit['dnu'], axis=0)[i], g2,
             c=next(colours2))
'''    
g1 = model(arr_n,
           np.mean(fit['dnu'], axis=0),
           np.mean(fit['nmax'], axis=0),
           np.mean(fit['epsilon'], axis=0),
           np.mean(fit['alpha'], axis=0))
           #np.mean(fit['A'], axis=0),
           #np.mean(fit['G'], axis=0),
           #np.mean(fit['phi'], axis=0),
           #np.mean(fit['tau'], axis=0))
    
plt.plot(g1 % np.mean(fit['dnu'], axis=0), g1, label='Fit_2D')
''' 
      

#print(arr_n[0])
print('Real dnu value:', dnu_avgID)
print('Stan dnu value:', np.mean(fit['dnu'], axis=0))
print('Stan nmax value:', np.mean(fit['nmax'], axis=0))
print('Stan ε value:', np.mean(fit['epsilon'], axis=0))
print('Stan α value:', np.mean(fit['alpha'], axis=0))


plt.legend()
plt.ylabel('Frequency')
plt.xlabel(r'Mod. Freq. Spacing ($\mu$Hz)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('seminar/somergbseizure.pdf', bbox='tight_layout')
# Out:
# Real dnu value: [4.126904543767577, 3.8496910311382195, 6.6509125622004825, 6.712070998339807, 4.675339590637959]
# Stan dnu value: [3.45768678 2.8011941  1.26161533 3.71009082 3.32257949]
# Stan nmax value: [ 7.31097921  7.67196531  9.48094392 10.91190225  8.21120071]
# Stan ε value: [ 0.66298164  0.83724559 73.39696105 34.48251008  3.43642239]
# Stan α value: [1.58332819e-05 1.92062057e-05 8.92381862e-05 7.47971627e-05
#  1.52558024e-05]

# %%
#fitdf = fit.to_dataframe(permuted=True)
#display(fitdf)
