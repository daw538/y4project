# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan

from IPython.display import display

from matplotlib import rc
rc("font", family="serif", size=11)

# %% [markdown]
# First we will read in a file that contains the overall list of all the available datasets, with corresponding star IDs, $\nu_{max}$ and $\sigma_{\nu_{max}}$ values. From this we will take a random selection for our analysis.

# %%
random.seed(121)
#output = pd.read_csv('../data/output_1000stars.csv', usecols=range(1,4))
output = pd.read_csv('../data/output_back_filesremoved.csv', usecols=['kic','numax', 'numax_err'])
output = output.loc[(np.abs(output['numax'] - 75) < 30.0)].reset_index(drop=True)
# Select a random number of stars from the file, recording their IDs
IDs = [random.choice(output['kic']) for i in range(6)]
IDs = [10802837,12003742,2283075,4760954,11358669,11521197]
# Create a list of the numax values corresponding to each ID
Numax = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax_err'] for i in range(len(IDs))]

# %% [markdown]
# Using our list of selected stars, we can then pull the respective files containing the induvidual mode frequencies and errors. The different files will contain varying numbers of modes; in order to successfully parse the data through Stan, one must ensure that all the arrays are of the same length. To do this, for every dataset that contains less modes than the most complete dataset, we can produce additional modes based on the average frequency spacing $\left<\Delta\nu\right>$ for each star, ensuring to assign these points with a large uncertainty so that Stan does not use this as restrictive points during the fit (they are essentially ignored).

# %%
modesID = [pd.read_csv('../data/rgbmodes/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0'])
           for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])


dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
    
dnu_avgarr = np.asarray(dnu_avgID)

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
A = 0.06*dnu_avgarr**(-0.88) 
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*10
phi = np.ones([len(IDs)])*1.71

# %% [markdown]
# The data for the different stars can be viewed on an Échelle Diagram.

# %%
plt.figure(1)
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

plt.ylabel('Frequency')
plt.xlabel(r'Mod. Freq. Spacing ('+ str(u"%.3f" % dnu_avg) +') $\mu$Hz')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.5)
#plt.savefig('seminar/manyrgbs.pdf')

plt.figure(2)
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))
plt.xlabel('Radial Order ($n$)')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# With all our required data, we can parse the data into a stan model constructed to perform a hierarchical Bayesian model. Hyperpriors have been introduced on a number of parameters based on values in the Vrard (2014) paper.
#
# The model follows the form:
# \begin{equation}
#     \left(n + \epsilon + \frac{\alpha}{2}\left(n-n_{max}\right)^2 + \frac{\mathcal{AG}}{2\pi}\sin\left(\frac{2\pi(n-n_{max})}{\mathcal{G}} + \phi \right)\right) e^{\frac{n}{\tau}}
# \end{equation}
# where
# \begin{equation}
#     n_{max} = \frac{\nu_{max}}{\Delta\nu} - \epsilon
# \end{equation}
#
#
# $$ A = A_0 e^{-n_{max}/\tau} \longrightarrow A_0 = A_{n_{max}} e^{n_{max}/\tau}$$

# %%
code = '''
functions {
    real glitch(real n, real dnu, real numax, real epsilon, real alpha, real A, real G, real phi, real tau){
        real nmax = numax/dnu - epsilon;
        return (n + epsilon + alpha/2 * (n-nmax)^2 + 
                A*G/(2*pi()) * sin((2*pi()*(n-nmax))/G + phi)) * dnu * exp(-(n-nmax)/tau);
    }
}
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M];
    real freq[N, M];
    real freq_err[N, M];
    real numax_obs[N];
    real numax_err[N];
    real dnu_guess[N];
}
parameters {
    real dnu[N];
    real numax[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N];
    //real<lower = 0> A[N];
    real epsilon[N];
    real<lower = 0> Anmax[N];
    real G[N];
    real<lower = 0> tau[N];
    
    // Hierarchical Parameters
    //real epsilon_std[N];
    //real<lower=0> eps_std;
    //real epsA;
    //real epsB;
    real alpha_std[N];
    real<lower=0> al_std;
    real alA;
    real alB;
    //real A_std[N];
    //real<lower=0> A_err;
    //real AA;
    //real AB;
    //real G_std[N];
    //real<lower=0> G_err;
    //real GA;
    
}

transformed parameters {
    //real epsilon[N];
    real alpha[N];
    //real A[N];
    //real G[N];
    real A0[N];
    
    for (i in 1:N){
        //epsilon[i] = epsilon_std[i] * eps_std + (epsA + epsB * log(dnu[i]));
        alpha[i] = alpha_std[i] * al_std + (alA * (dnu[i])^(-alB));
        //A[i] = A_std[i] * A_err + (AA * (dnu[i])^(-AB));
        //G[i] = G_std[i] * G_err + GA;
        A0[i] = Anmax[i] * exp((numax[i]/dnu[i] - epsilon[i])/tau[i]);
    }
}

model {
    real mod[M];
    for (i in 1:N){
        for (j in 1:M){
            mod[j] = glitch(n[i,j], dnu[i], numax[i], epsilon[i], alpha[i], A0[i], G[i], phi[i], tau[i]);
            // mod[j] ~ normal(freq[i], freq_err[i]);
        }
        freq[i,:] ~ normal(mod, freq_err[i,:]);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.001);
        Anmax[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.4);
        epsilon[i] ~ normal(0.601 + 0.632*log10(dnu[i]), 0.5);
    }
    
    //epsilon ~ uniform(-1.0, 2.0);
    //nmax ~ normal(10, 4);
    //alpha ~ lognormal(log(0.015*dnu^(-0.32)), 0.3);
    
    G ~ normal(3.08, 0.65);
    
    numax ~ normal(numax_obs, numax_err);
    
    tau ~ normal(10, 10);
    
    // Hierarchical Hyperpriors
    //epsilon_std ~ normal(0, 1);
    //eps_std ~ normal(0, 0.5);
    //epsA ~ normal(0.601, 0.25);
    //epsB ~ normal(0.632, 0.25);
    alpha_std ~ normal(0, 1);
    al_std ~ normal(0, 0.5);    
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    //A_std ~ normal(0, 1);
    //A_err ~ normal(0, 0.5);
    //AA ~ normal(0.06, 0.02);
    //AB ~ normal(0.88, 0.05);
    //G_std ~ normal(0, 1);
    //G_err ~ normal(0.65, 0.5);
    //GA ~ normal(3.08, 0.1);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_cf9481015a01108502163a589ab98401 NOW.

# %%
no_tau = pd.read_csv('no_tau_models.csv', names=['dnu', 'numax', 'epsilon', 'alpha', 'A', 'G', 'phi', 'tau'])

stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'numax_obs': Numax,
         'numax_err': Numax_err,
         'dnu_guess': dnu_avgarr
        }
start = {'dnu': dnu_avgarr,
         'numax': Numax,
         'eps_std': 0.01,
         'al_std': 0.01,
         'A_err': 0.01,
         #'G_err': 0.65,
         'epsilon': no_tau['epsilon'].values,
         'alpha': no_tau['alpha'].values,
         #'A0': no_tau['A'].values,
         'G': no_tau['G'].values,
         'phi': no_tau['phi'].values,
         #'epsA': 0.601,
         #'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
         #'AA': 0.06,
         #'AB': 0.88,
         #'GA': 3.08
         'tau': tau
    }
nchains = 4

fit = sm.sampling(data=stan_data, iter=5000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[6] is 0.000803667072128739!
# WARNING:pystan:n_eff / iter for parameter numax[3] is 0.0002939991322524567!
# WARNING:pystan:n_eff / iter for parameter phi[3] is 0.00028714195023308664!
# WARNING:pystan:n_eff / iter for parameter phi[4] is 0.00021163273606235834!
# WARNING:pystan:n_eff / iter for parameter phi[5] is 0.000627734710984984!
# WARNING:pystan:n_eff / iter for parameter phi[6] is 0.00021906152380652726!
# WARNING:pystan:n_eff / iter for parameter epsilon[3] is 0.0002996592295814148!
# WARNING:pystan:n_eff / iter for parameter epsilon[6] is 0.0009458853227326667!
# WARNING:pystan:n_eff / iter for parameter Anmax[4] is 0.0005249897668759926!
# WARNING:pystan:n_eff / iter for parameter Anmax[5] is 0.0002586545925958755!
# WARNING:pystan:n_eff / iter for parameter Anmax[6] is 0.0002047872096681584!
# WARNING:pystan:n_eff / iter for parameter G[3] is 0.0003138239153518612!
# WARNING:pystan:n_eff / iter for parameter G[4] is 0.00020548854706328945!
# WARNING:pystan:n_eff / iter for parameter G[5] is 0.00020392659954961804!
# WARNING:pystan:n_eff / iter for parameter G[6] is 0.00020064500168141732!
# WARNING:pystan:n_eff / iter for parameter tau[3] is 0.0009112483559484401!
# WARNING:pystan:n_eff / iter for parameter tau[6] is 0.00021415533086381594!
# WARNING:pystan:n_eff / iter for parameter alpha_std[3] is 0.00032988067377525744!
# WARNING:pystan:n_eff / iter for parameter alpha_std[6] is 0.0006334445358226462!
# WARNING:pystan:n_eff / iter for parameter alpha[3] is 0.0002949070540381632!
# WARNING:pystan:n_eff / iter for parameter alpha[6] is 0.0003673384007587611!
# WARNING:pystan:n_eff / iter for parameter A0[4] is 0.000526238642008954!
# WARNING:pystan:n_eff / iter for parameter A0[5] is 0.00025866402339226477!
# WARNING:pystan:n_eff / iter for parameter A0[6] is 0.00020563335146305258!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.00021471160584088608!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[6] is 1.1473182959374602!
# WARNING:pystan:Rhat for parameter numax[3] is 2.2143559959067933!
# WARNING:pystan:Rhat for parameter phi[3] is 2.285310394133709!
# WARNING:pystan:Rhat for parameter phi[4] is 4.05969478014307!
# WARNING:pystan:Rhat for parameter phi[5] is 1.2016191256203406!
# WARNING:pystan:Rhat for parameter phi[6] is 3.3078525426673275!
# WARNING:pystan:Rhat for parameter epsilon[3] is 2.0724139684759475!
# WARNING:pystan:Rhat for parameter epsilon[6] is 1.1519590800273134!
# WARNING:pystan:Rhat for parameter Anmax[4] is 1.2571251451572731!
# WARNING:pystan:Rhat for parameter Anmax[5] is 2.0150119225734424!
# WARNING:pystan:Rhat for parameter Anmax[6] is 6.439264784751745!
# WARNING:pystan:Rhat for parameter G[3] is 2.039909413370057!
# WARNING:pystan:Rhat for parameter G[4] is 5.7971617443406815!
# WARNING:pystan:Rhat for parameter G[5] is 6.840000376970124!
# WARNING:pystan:Rhat for parameter G[6] is 17.14401909831593!
# WARNING:pystan:Rhat for parameter tau[3] is 1.1711170483756155!
# WARNING:pystan:Rhat for parameter tau[6] is 3.696976774582099!
# WARNING:pystan:Rhat for parameter alpha_std[3] is 1.8888368602742591!
# WARNING:pystan:Rhat for parameter alpha_std[6] is 1.2082130914823273!
# WARNING:pystan:Rhat for parameter alpha[3] is 2.1674512132440227!
# WARNING:pystan:Rhat for parameter alpha[6] is 1.4463994925633896!
# WARNING:pystan:Rhat for parameter A0[4] is 1.2563569923405402!
# WARNING:pystan:Rhat for parameter A0[5] is 2.014841757862956!
# WARNING:pystan:Rhat for parameter A0[6] is 5.94433771508894!
# WARNING:pystan:Rhat for parameter lp__ is 4.3197350515638675!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:7 of 10000 iterations ended with a divergence (0.07%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:2500 of 10000 iterations saturated the maximum tree depth of 10 (25.0%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_6cc1e34c5a01d1e0b2b90681b89693fe.
# 4 chains, each with iter=5000; warmup=2500; thin=1;
# post-warmup draws per chain=2500, total post-warmup draws=10000.
#
#                mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]         5.49  1.1e-3 5.8e-3   5.48   5.48   5.49   5.49    5.5     28   1.06
# dnu[2]         5.42  1.2e-4 5.3e-3   5.41   5.42   5.42   5.42   5.43   1810   1.01
# dnu[3]         6.45  6.2e-3   0.02   6.43   6.44   6.44   6.45   6.51      7    1.6
# dnu[4]         4.77  1.1e-4 4.7e-3   4.77   4.77   4.77   4.78   4.78   1745    1.0
# dnu[5]         8.64  9.8e-4 6.2e-3   8.63   8.64   8.64   8.65   8.65     39   1.07
# dnu[6]         6.17  2.3e-3 6.8e-3   6.15   6.16   6.17   6.17   6.18      9   1.14
# tau[5]       312.07    0.54   5.32 301.68 308.41 312.02 315.88 322.16     97   1.04
# tau[6]       104.67   14.07  20.77   70.2  85.44 108.91 123.81 133.85      2   3.38
# alpha_std[1]   1.28    0.33   0.66   0.33   0.77   1.18    1.7   2.76      4   1.43
# alpha_std[2]   0.79    0.18   0.38   0.26   0.51   0.71   1.01   1.73      5   1.36
# alpha_std[3]   0.31    0.59   1.02  -1.23  -0.46  -0.08   1.12    2.4      3   1.94
# alpha_std[4]   0.69    0.16   0.33   0.22   0.44   0.62   0.87    1.5      5   1.36
# alpha_std[5]   0.18    0.04   0.11   0.02    0.1   0.16   0.24   0.44      7   1.19
# alpha_std[6]   0.34    0.16    0.3  -0.13   0.14   0.29   0.48   1.07      4   1.52
# al_std         0.06    0.01   0.03   0.02   0.04   0.05   0.07   0.14      7   1.22
# alA            0.02  7.4e-5 5.1e-3 6.4e-3   0.01   0.02   0.02   0.03   4660    1.0
# alB            0.31  1.2e-3   0.08   0.15   0.25   0.31   0.36   0.47   4553    1.0
# alpha[1]       0.08    0.03   0.04   0.03   0.04   0.07   0.12   0.13      2   4.87
# alpha[2]       0.05  2.6e-5 1.8e-3   0.04   0.04   0.05   0.05   0.05   4584    1.0
# alpha[3]       0.03    0.03   0.05  -0.03  -0.01 4.9e-3   0.08   0.09      3   2.67
# alpha[4]       0.04  3.9e-5 1.6e-3   0.04   0.04   0.04   0.04   0.04   1586   1.01
# alpha[5]       0.02  3.2e-4 7.3e-4   0.02   0.02   0.02   0.02   0.02      5   1.27
# alpha[6]       0.02  5.4e-3 9.8e-3 5.3e-3   0.02   0.03   0.03   0.04      3   1.62
# A0[1]          1.32    0.84    1.2   0.12   0.15   0.87   2.47   3.13      2   5.02
# A0[2]          0.27    0.02   0.04    0.2   0.24   0.26    0.3   0.36      5   1.32
# A0[3]          0.12    0.01   0.03   0.03   0.11   0.12   0.13   0.16      5   1.99
# A0[4]          0.17    0.05   0.08   0.08   0.11   0.14    0.2   0.37      2   2.46
# A0[5]          0.03  6.9e-3   0.01 5.5e-3   0.02   0.03   0.04   0.04      2   2.79
# A0[6]         12.94   14.47  20.67    0.1   0.11   1.09  20.33  55.83      2   7.55
# lp__          -2464   92.34 141.57  -2865  -2533  -2436  -2363  -2305      2   4.12
#
# Samples were drawn using NUTS at Fri Feb 15 10:51:52 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
#%matplotlib inline
def model(n,dnu,numax,eps,alpha,A,G,phi,tau):
    nmax = numax/dnu - eps
    s = (n + eps + ((alpha/2)*(nmax-n)**2) +
         (((A*G)/(2*np.pi)) * np.sin((2*np.pi*(n-nmax))/G + phi)))*dnu*np.exp(-(n-nmax)/(tau))
    return s


fig = plt.figure(1, figsize=(12,4))
ax  = fig.add_subplot(111)
ax.set_position([0.1,0.1,0.6,0.85])

import itertools
colours = itertools.cycle(('r', 'orange', 'olive', 'teal', 'sienna', 'indigo'))
    
for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    ax.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    ax.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    ax.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)      
    
    # Plot the modelled fit
    g2 = model(arr_n[i],
           np.mean(fit['dnu'], axis=0)[i],
           np.mean(fit['numax'], axis=0)[i],
           np.mean(fit['epsilon'], axis=0)[i],
           np.mean(fit['alpha'], axis=0)[i],
           np.mean(fit['A0'], axis=0)[i],
           np.mean(fit['G'], axis=0)[i],
           np.mean(fit['phi'], axis=0)[i],
           np.mean(fit['tau'], axis=0)[i]
              )
    
    ax.plot(g2 % np.mean(fit['dnu'], axis=0)[i], g2,
             c=colour)
'''    
g1 = model(arr_n[0],
           np.mean(fit['dnu'], axis=0)[0],
           np.mean(fit['nmax'], axis=0)[0],
           np.mean(fit['epsilon'], axis=0)[0],
           np.mean(fit['alpha'], axis=0)[0],
           np.mean(fit['A'], axis=0)[0],
           np.mean(fit['G'], axis=0)[0],
           np.mean(fit['phi'], axis=0)[0],
           np.mean(fit['tau'], axis=0)[0])
    
plt.plot(g1 % np.mean(fit['dnu'], axis=0)[0], g1,
             label='Fit_2D')
 
'''       

print(arr_n[0])
print(np.mean(fit['dnu'], axis=0))
print(dnu_avgID)
print(np.mean(fit['numax'], axis=0))
print(np.mean(fit['epsilon'], axis=0))
print(np.mean(fit['alpha'], axis=0))
print(np.mean(fit['A0'], axis=0))
print(np.mean(fit['G'], axis=0))
print(np.mean(fit['phi'], axis=0))
#print(np.mean(fit['tau'], axis=0))


plt.legend()
plt.ylabel('Frequency')
plt.xlabel(r'Mod. Freq. Spacing ($\mu$Hz)')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
#plt.savefig('seminar/somergbseizure.pdf', bbox='tight_layout')
# Out:
# [ 8.  9. 10. 11. 12. 13. 14. 15.]
# [5.48938233 5.41936584 6.4418953  4.77460637 8.6417396  6.1689634 ]
# [5.483661167259889, 5.391717113012496, 6.425904630453945, 4.7540210409470065, 8.425621833114374, 6.1615878856256625]
# [53.12188377 52.32929828 68.58729866 40.91227743 95.03385373 67.61005476]
# [-0.10821524  0.13412428  0.30965634  0.89504061 -0.08602405  0.13940107]
# [0.11784575 0.04553958 0.00734482 0.04127344 0.01671467 0.02087189]
# [0.14825574 0.25476726 0.12927123 0.12340398 0.02869138 0.9640114 ]
# [ 7.7052322   2.18786424 12.95662899  2.03781791  2.32412867  9.404963  ]
# [ 0.74894785 -4.01593511 -0.38300291 -2.56638615  1.78471443  0.40806274]

# %%
# %matplotlib inline
plt.figure(2)
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))
plt.xlabel('Radial Order ($n$)')
plt.ylabel('Frequency')
plt.legend()
plt.show()


fig, ax = plt.subplots(len(IDs))
for i in np.arange(0,len(IDs),1):
    ax[i].errorbar(modesID[i]['n'], modesID[i]['f0'] - g2, yerr=modesID[i]['f0_err']*10)
    #ax[i].set_xlim([6,20])
    #ax[i].set_ylim([-3.5, 3.5])
    ax[i].set_ylim([-15, 15])
    
plt.show()

# %%
no_osc = np.loadtxt('/home/daniel/Documents/y4project/Dan_notebooks/no_osc_models.csv', delimiter=',')


fig = plt.figure(1, figsize=(12,4))
ax  = fig.add_subplot(111)
ax.set_position([0.1,0.1,0.6,0.85])

import itertools
colours = itertools.cycle(('r', 'orange', 'olive', 'teal', 'sienna', 'indigo'))

osc = []
for i in np.arange(0,len(IDs),1):
    colour = next(colours)
    ax.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    ax.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    ax.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)      
    
    # Plot the modelled fit
    g2 = model(arr_n[i],
           np.mean(fit['dnu'], axis=0)[i],
           np.mean(fit['numax'], axis=0)[i],
           np.mean(fit['epsilon'], axis=0)[i],
           np.mean(fit['alpha'], axis=0)[i],
           np.mean(fit['A0'], axis=0)[i],
           np.mean(fit['G'], axis=0)[i],
           np.mean(fit['phi'], axis=0)[i],
           np.mean(fit['tau'], axis=0)[i]
              )
    ax.plot(g2 % np.mean(fit['dnu'], axis=0)[i], g2,
             c=colour)
    ax.plot(no_osc[i] % dnu_avgID[i], no_osc[i], linestyle=':', c=colour)
    osc.append(g2)

colours = itertools.cycle(('r', 'orange', 'olive', 'teal', 'sienna', 'indigo'))
fig, ax = plt.subplots(len(IDs), figsize=(5,14))
for i in np.arange(0,len(IDs),1):
    #ax[i].scatter(no_osc[i], (no_osc[i] % dnu_avgID[i]))
    #ax[i].scatter(osc[i], (osc[i] % dnu_avgID[i]))
    ax[i].scatter(no_osc[i], (no_osc[i] % dnu_avgID[i])-(osc[i] % np.mean(fit['dnu'], axis=0)[i]), c=next(colours))
plt.xlabel(r'Freqency ($\mu$Hz)')
plt.show()

# %%
no_tau = np.loadtxt('/home/daniel/Documents/y4project/Dan_notebooks/no_tau_models.csv', delimiter=',')
no_tau = pd.read_csv('no_tau_models.csv', names=['dnu', 'numax', 'epsilon', 'alpha', 'A', 'G', 'phi', 'tau'])
no_tau
# Out:
#         dnu      numax   epsilon     alpha         A         G       phi  tau
# 0  5.483315  57.263652  0.029768  0.014692  0.037512  2.700290  0.852972  NaN
# 1  5.394925  59.846463  0.169461  0.013854  0.077494  2.586622 -0.043143  NaN
# 2  6.449046  67.676914  0.169412  0.013481  0.029490  2.673891  1.557981  NaN
# 3  4.747841  45.746180  0.917655  0.013181  0.038654  3.097227  0.140495  NaN
# 4  8.432162  98.099118  0.188873  0.011033  0.021136  2.814720  2.384268  NaN
# 5  6.166735  67.642849  0.103137  0.011543  0.039744  2.377497  2.624294  NaN
