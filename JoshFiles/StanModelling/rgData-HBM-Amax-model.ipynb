# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan
import os

from IPython.display import display

from matplotlib import rc
rc("font", family="serif", size=11)

import itertools
colours = itertools.cycle(('r', 'orange', 'olive', 'teal', 'sienna', 'indigo'))

# %%
#Import output data
output = pd.read_csv('../data/output_back_filesremoved.csv', usecols=[1,11,24])
#IDs = [(output.loc[output['ID'] == random.choice(output['ID'])]).iloc[0]['Numax'] for i in range(5)]
df_met = pd.read_csv('../data/APOKASCfull.csv')

#Set numax range so stars are chosen with similar size echelles
rng = 30
numax_tgt = 75
output = output.loc[(np.abs(output['numax'] - numax_tgt) < rng)].reset_index(drop=True)

#Number of stars to model
nStars = 5

#Selects a random sample of stars from the file, recording their IDs and makes sure the stars exist in APOKASC file
IDs = []*nStars
i = 0
while i < nStars:
    nextID = random.choice(output['kic'])
    for j in range(len(df_met.KIC)):
        if nextID == df_met.KIC[j]:
            IDs.append(nextID)
            i += 1
#IDs = [random.choice(output['kic']) for i in range(nStars)]

# Create a list of the numax values and errors corresponding to each ID
Numax = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax_err'] for i in range(len(IDs))]

print(IDs)
# Out:
# [5112387, 11134982, 9408361, 4469886, 8759207]

# %%
#Create acyclic graph (probabalistic graphical model)
from matplotlib import rc
rc("font", family="serif", size=16)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("AA", r"$AA_{RGB}$", 1.0, 2.6))
pgm.add_node(daft.Node("AB", r"$AB_{RGB}$", 2.0, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("A_true", r"$A_{{\rm true},i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("A_obs", r"$A_{{\rm obs},i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("Aerr", r"$\sigma_{A_{{\rm obs},i}}$", 0.4, 0.8, fixed=True, offset=[0.0,0.4]))
# Add in the edges.
pgm.add_edge("AA", "A_true")
pgm.add_edge("AB", "A_true")
pgm.add_edge("A_obs", "A_true")
pgm.add_edge("Aerr", "A_obs")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.4, 2.7, 1.7], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()

# %%
#Import mode data and construct arrays for storing orders and frequencies
modesID = [pd.read_csv('../data/rgbmodes/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0']) for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])

#Sort values by frequency and assign order and calculate avg dnu
dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    #(due to some stars having fewer mode frequencies observed)
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            #modesID[i].loc[l] = [l, int(np.max(modesID[i]['n']+l)), (np.max(modesID[i]['dnu'])+dnu_avgID[i]), np.nan , 10000]
            #app = pd.DataFrame([(np.max(modesID[i]['dnu'])+dnu_avgID[i]), 10000], columns=['n', 'f0', 'f0_err'])
            #modesID[i].append(app, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
dnu_avgarr = np.asarray(dnu_avgID)

# %%
#Construct and plot echelles for each star
for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label=r'ID = '+str(IDs[i]), zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    plt.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    plt.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)
#for i in np.arange(0,len(IDs),1):
    #plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
numax_err = Numax_err
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
#A = 0.06*dnu_avgarr**(-0.88) 
A = 0.06*dnu_avgarr**(-0.88)
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*10
phi = np.ones([len(IDs)])*1.71

plt.ylabel('Frequency')
plt.xlabel(r'Frequency modulo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# $A_{n_{max}} = A_0 e^{-\frac{n}{\tau}}$
#
# Rearrange for A0 is transformed parameter

# %%
code = '''
functions{
    real asex(real n, real dnu, real nmax, real epsilon, real alpha, real A0, real G, real phi, real tau){
        return (n + epsilon + (alpha/2) * (nmax - n)^2 + 
                A0*G/(2*pi()) * sin((2*pi()*(n-nmax))/G + phi))*dnu
                *exp(-n/tau);
    }
}
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M]; //order
    real freq[N, M]; //mode frequency
    real freq_err[N, M]; //uncertainty in mode frequency
    real dnu_guess[N];  //calculated estimate of dnu
    real numax_obs[N];  //calculated numax from data
    real numax_err[N];  //error in numax
}
parameters {
    real dnu[N];
    real<lower = 0> numax[N];
    
    real epsilon_std[N];
    real<lower = 0> eps_sig;
    real epsA;
    real epsB;
    
    real alpha_std[N];
    real<lower = 0> al_sig;
    real alA;
    real alB;
    
    //real A_std[N];
    //real<lower = 0> A_sig;
    real<lower = 0> A[N];
    //real AA;
    //real AB;
    
    real<lower = 0> G[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N];
    real<lower = 0> tau[N];
    
}

transformed parameters{
    real epsilon[N];
    real alpha[N];
    //real A[N];
    for (i in 1:N){
        epsilon[i] = epsilon_std[i] * eps_sig + (epsA + epsB * log(dnu[i]));
        alpha[i] = alpha_std[i] * al_sig + (alA * (dnu[i])^(-alB));
        //A[i] = A_std[i] * A_sig + (AA*dnu[i]^(-AB));
    }
}
model {
    real mod[M];
    real nmax[N];
    real A0[N];
    //real A[N];
    for (i in 1:N){
        nmax[i] = numax[i]/dnu[i] - epsilon[i];
        A0[i] = A[i]*exp(nmax[i]/tau[i]);
        for (j in 1:M){
            mod[j] = asex(n[i,j], dnu[i], nmax[i], epsilon[i], alpha[i], A0[i], G[i], phi[i], tau[i]);
            //mod[j] ~ normal(freq[i], freq_err[i]);
        }
        freq[i,:] ~ normal(mod, freq_err[i,:]);
        numax[i] ~ normal(numax_obs[i], numax_err[i]);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.01);
        //epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        //alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
        //A0[i] ~ lognormal(log(AA*dnu[i]^(-AB)), 0.4);
        A[i] ~ lognormal(log(A0[i]*exp(nmax[i]/tau[i])), 0.4);
        //A[i] ~ normal(0.01, 0.4);
        //epsilon[i] ~ uniform(-1.0, 2.0);
        //alpha[i] ~ lognormal(log(0.015*dnu[i]^(-0.32)), 0.5);
        A0[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.6);
    }
    nmax ~ normal(10, 4);
    G ~ normal(3.08, 0.65);
    tau ~ normal(30, 10);
    epsilon_std ~ normal(0, 1);
    eps_sig ~ normal(0, 0.5);
    epsA ~ normal(0.601, 0.08);
    epsB ~ normal(0.632, 0.08);
    alpha_std ~ normal(0, 1);
    al_sig ~ normal(0, 0.5); 
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    //A_std ~ normal(0, 1);
    //A_sig ~ normal(0, 0.5);
    //AA ~ normal(0.06, 0.01);
    //AB ~ normal(0.88, 0.05);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_82d8dc35eeb8bb1c15232ad37ec070eb NOW.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/2_/b8v0t8pn1hj1p3r4lyfvvv2h0000gn/T/tmp_t5wv4ju/stanfit4anon_model_82d8dc35eeb8bb1c15232ad37ec070eb_3083231441676782332.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr,
         'numax_obs': numax_obs,
         'numax_err': numax_err
        }
start = {'dnu': dnu_avgarr,
         'nmax': nmax,
         'numax': numax_obs,
         #'epsilon': epsilon,
         #'alpha': alpha,
         'A0': A,
         'A': 0.0001*np.ones([len(IDs)]),
         'eps_sig': 0.01,
         'al_sig': 0.01,
         'A_sig': 0.01,
         'G': G,
         'tau': tau,
         'phi': phi,
         'epsA': 0.601,
         'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
         'AA': 0.06,
         'AB': 0.88
        }
nchains = 4

fit = sm.sampling(data=stan_data, iter=5000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[1] is 0.00020785751436673176!
# WARNING:pystan:n_eff / iter for parameter dnu[2] is 0.00021108771274320372!
# WARNING:pystan:n_eff / iter for parameter dnu[3] is 0.00021119376728702654!
# WARNING:pystan:n_eff / iter for parameter dnu[4] is 0.00031116444981863325!
# WARNING:pystan:n_eff / iter for parameter numax[1] is 0.00021252937815787381!
# WARNING:pystan:n_eff / iter for parameter numax[2] is 0.0002004427307836016!
# WARNING:pystan:n_eff / iter for parameter numax[3] is 0.00022361203098530952!
# WARNING:pystan:n_eff / iter for parameter numax[4] is 0.00021028734918682713!
# WARNING:pystan:n_eff / iter for parameter numax[5] is 0.00020250284182451455!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[1] is 0.0002164147972974491!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[2] is 0.00020372665020988238!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[3] is 0.0002866255293116113!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[4] is 0.00022228279138869497!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[5] is 0.00020342596721953615!
# WARNING:pystan:n_eff / iter for parameter eps_sig is 0.00021139238548275387!
# WARNING:pystan:n_eff / iter for parameter epsA is 0.00020237727172734888!
# WARNING:pystan:n_eff / iter for parameter epsB is 0.0002010640756615301!
# WARNING:pystan:n_eff / iter for parameter alpha_std[1] is 0.00023785117967322896!
# WARNING:pystan:n_eff / iter for parameter alpha_std[2] is 0.00021906881237622553!
# WARNING:pystan:n_eff / iter for parameter alpha_std[3] is 0.00020030278370332657!
# WARNING:pystan:n_eff / iter for parameter alpha_std[4] is 0.00021841949771475875!
# WARNING:pystan:n_eff / iter for parameter alpha_std[5] is 0.00020011555882882832!
# WARNING:pystan:n_eff / iter for parameter al_sig is 0.0002882293078650134!
# WARNING:pystan:n_eff / iter for parameter alA is 0.0002540194163644663!
# WARNING:pystan:n_eff / iter for parameter alB is 0.0002002181551794354!
# WARNING:pystan:n_eff / iter for parameter A[1] is 0.0002273098651314032!
# WARNING:pystan:n_eff / iter for parameter A[2] is 0.00020008482840767745!
# WARNING:pystan:n_eff / iter for parameter A[3] is 0.0003193835230199592!
# WARNING:pystan:n_eff / iter for parameter A[4] is 0.00023666263745781798!
# WARNING:pystan:n_eff / iter for parameter A[5] is 0.000265302416893446!
# WARNING:pystan:n_eff / iter for parameter G[1] is 0.0002530360363815452!
# WARNING:pystan:n_eff / iter for parameter G[2] is 0.00020005793326305374!
# WARNING:pystan:n_eff / iter for parameter phi[1] is 0.0002040937689949156!
# WARNING:pystan:n_eff / iter for parameter phi[2] is 0.00020030742932243575!
# WARNING:pystan:n_eff / iter for parameter phi[3] is 0.00020664805030696192!
# WARNING:pystan:n_eff / iter for parameter phi[4] is 0.00020852187653185985!
# WARNING:pystan:n_eff / iter for parameter phi[5] is 0.0002047451615963728!
# WARNING:pystan:n_eff / iter for parameter tau[1] is 0.0002000407079591824!
# WARNING:pystan:n_eff / iter for parameter tau[2] is 0.00020112743970215639!
# WARNING:pystan:n_eff / iter for parameter tau[3] is 0.00020170661533993245!
# WARNING:pystan:n_eff / iter for parameter tau[4] is 0.0002018456482430416!
# WARNING:pystan:n_eff / iter for parameter tau[5] is 0.00020032844773855055!
# WARNING:pystan:n_eff / iter for parameter epsilon[1] is 0.00020038783350775007!
# WARNING:pystan:n_eff / iter for parameter epsilon[2] is 0.00022336853458146356!
# WARNING:pystan:n_eff / iter for parameter epsilon[3] is 0.00024446311212496095!
# WARNING:pystan:n_eff / iter for parameter epsilon[4] is 0.0003177143322285684!
# WARNING:pystan:n_eff / iter for parameter epsilon[5] is 0.00020172898213130988!
# WARNING:pystan:n_eff / iter for parameter alpha[1] is 0.00020075928601554974!
# WARNING:pystan:n_eff / iter for parameter alpha[2] is 0.00020020317128748735!
# WARNING:pystan:n_eff / iter for parameter alpha[3] is 0.0002006028911127206!
# WARNING:pystan:n_eff / iter for parameter alpha[4] is 0.00020044811801670303!
# WARNING:pystan:n_eff / iter for parameter alpha[5] is 0.00020019840728855538!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.0002000401192011767!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[1] is 5.2725304660507!
# WARNING:pystan:Rhat for parameter dnu[2] is 4.552741001006105!
# WARNING:pystan:Rhat for parameter dnu[3] is 4.978595523585846!
# WARNING:pystan:Rhat for parameter dnu[4] is 2.3319405024010904!
# WARNING:pystan:Rhat for parameter dnu[5] is 1.2106634938416019!
# WARNING:pystan:Rhat for parameter numax[1] is 4.448741266900757!
# WARNING:pystan:Rhat for parameter numax[2] is 23.833850224541678!
# WARNING:pystan:Rhat for parameter numax[3] is 3.553432226632014!
# WARNING:pystan:Rhat for parameter numax[4] is 5.7222636548444585!
# WARNING:pystan:Rhat for parameter numax[5] is 9.725063772666967!
# WARNING:pystan:Rhat for parameter epsilon_std[1] is 4.374649906398094!
# WARNING:pystan:Rhat for parameter epsilon_std[2] is 9.064274660892767!
# WARNING:pystan:Rhat for parameter epsilon_std[3] is 2.300885413537008!
# WARNING:pystan:Rhat for parameter epsilon_std[4] is 3.73035979005858!
# WARNING:pystan:Rhat for parameter epsilon_std[5] is 9.385507913320653!
# WARNING:pystan:Rhat for parameter eps_sig is 5.347870996703617!
# WARNING:pystan:Rhat for parameter epsA is 9.625077354431307!
# WARNING:pystan:Rhat for parameter epsB is 14.23517316283604!
# WARNING:pystan:Rhat for parameter alpha_std[1] is 4.155693915671489!
# WARNING:pystan:Rhat for parameter alpha_std[2] is 5.631899100746265!
# WARNING:pystan:Rhat for parameter alpha_std[3] is 39.01420556269547!
# WARNING:pystan:Rhat for parameter alpha_std[4] is 4.979616147152569!
# WARNING:pystan:Rhat for parameter alpha_std[5] is 71.97085506242165!
# WARNING:pystan:Rhat for parameter al_sig is 2.322549827850647!
# WARNING:pystan:Rhat for parameter alA is 2.2174926890416646!
# WARNING:pystan:Rhat for parameter alB is 34.558208282157274!
# WARNING:pystan:Rhat for parameter A[1] is 2.9986925194443956!
# WARNING:pystan:Rhat for parameter A[2] is 69.95329703517278!
# WARNING:pystan:Rhat for parameter A[3] is 1.7726388768001562!
# WARNING:pystan:Rhat for parameter A[4] is 2.6879264897904296!
# WARNING:pystan:Rhat for parameter A[5] is 2.3958501221142927!
# WARNING:pystan:Rhat for parameter G[1] is 2.323188221358705!
# WARNING:pystan:Rhat for parameter G[2] is 116.70301337716042!
# WARNING:pystan:Rhat for parameter G[3] is 1.327996647440102!
# WARNING:pystan:Rhat for parameter G[4] is 1.2292132606481467!
# WARNING:pystan:Rhat for parameter G[5] is 1.1094474058603656!
# WARNING:pystan:Rhat for parameter phi[1] is 7.476168375334118!
# WARNING:pystan:Rhat for parameter phi[2] is 29.746127073865043!
# WARNING:pystan:Rhat for parameter phi[3] is 5.803757210222!
# WARNING:pystan:Rhat for parameter phi[4] is 5.812783266523996!
# WARNING:pystan:Rhat for parameter phi[5] is 7.717905860358294!
# WARNING:pystan:Rhat for parameter tau[1] is 530.590752972085!
# WARNING:pystan:Rhat for parameter tau[2] is 13.992165631894975!
# WARNING:pystan:Rhat for parameter tau[3] is 11.40242216551051!
# WARNING:pystan:Rhat for parameter tau[4] is 12.471299161211194!
# WARNING:pystan:Rhat for parameter tau[5] is 27.332777707805686!
# WARNING:pystan:Rhat for parameter epsilon[1] is 24.46819804631771!
# WARNING:pystan:Rhat for parameter epsilon[2] is 3.2899980340238284!
# WARNING:pystan:Rhat for parameter epsilon[3] is 2.8050509337182064!
# WARNING:pystan:Rhat for parameter epsilon[4] is 2.2588609747494965!
# WARNING:pystan:Rhat for parameter epsilon[5] is 11.679008206620974!
# WARNING:pystan:Rhat for parameter alpha[1] is 16.954893565252338!
# WARNING:pystan:Rhat for parameter alpha[2] is 35.055490874924416!
# WARNING:pystan:Rhat for parameter alpha[3] is 18.65425855408508!
# WARNING:pystan:Rhat for parameter alpha[4] is 21.60050747984586!
# WARNING:pystan:Rhat for parameter alpha[5] is 36.17760825642025!
# WARNING:pystan:Rhat for parameter lp__ is 1611.9561892999245!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:10000 of 10000 iterations saturated the maximum tree depth of 10 (100.0%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_82d8dc35eeb8bb1c15232ad37ec070eb.
# 4 chains, each with iter=5000; warmup=2500; thin=1;
# post-warmup draws per chain=2500, total post-warmup draws=10000.
#
#                  mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]           4.78    0.13   0.19    4.6   4.66    4.7   4.97   5.11      2   5.27
# dnu[2]           8.73    0.07    0.1   8.62   8.65   8.68   8.84    8.9      2   4.55
# dnu[3]            5.9    0.06   0.08   5.76   5.82   5.94   5.96    6.0      2   4.98
# dnu[4]           6.15    0.02   0.04   6.09   6.09   6.15   6.18   6.22      3   2.33
# dnu[5]           8.01  7.8e-3   0.03   7.95   7.99   8.02   8.04   8.05     13   1.21
# numax[1]        45.52     0.8   1.17  44.26  44.72  44.98  46.92  47.48      2   4.45
# numax[2]       110.65    4.32   6.12  106.1 107.01 107.34 115.23 121.32      2  23.83
# numax[3]        61.17    0.87    1.3  59.52  60.23  60.74  62.88  63.31      2   3.55
# numax[4]        53.42    1.76   2.55  49.14  50.88  54.51  55.27  55.99      2   5.72
# numax[5]        78.79    1.67   2.38  74.69  76.55  80.03   80.3   80.7      2   9.73
# epsilon_std[1]   1.61    0.57   0.84   0.21   0.71   1.97   2.18    2.6      2   4.37
# epsilon_std[2]   -1.0    0.89   1.27  -2.12   -1.8  -1.63   0.12   1.18      2   9.06
# epsilon_std[3]  -1.14    0.15   0.25  -1.59  -1.32  -1.19  -0.82  -0.78      3    2.3
# epsilon_std[4]  -0.98    0.27    0.4  -1.51  -1.25  -1.13  -0.55  -0.33      2   3.73
# epsilon_std[5]  -0.72    0.74   1.06  -1.66  -1.38  -1.25   0.19   1.11      2   9.39
# eps_sig           1.3    0.53   0.77 9.9e-3   0.56   1.63    1.8   2.21      2   5.35
# epsA             0.89    0.41   0.58   0.42   0.53   0.59   1.39   1.89      2   9.63
# epsB             0.11    0.59   0.83  -1.33  -0.55   0.55   0.61   0.74      2  14.24
# alpha_std[1]     1.53    1.04    1.6  -0.95  -0.15   1.88   2.61   4.02      2   4.16
# alpha_std[2]    -0.11    0.15   0.22  -0.43  -0.25  -0.19    0.1   0.24      2   5.63
# alpha_std[3]    -0.18    0.27   0.38  -0.84  -0.46   0.03   0.05   0.08      2  39.01
# alpha_std[4]     0.02    0.04   0.05  -0.07  -0.03   0.04   0.06   0.09      2   4.98
# alpha_std[5]    -0.33    0.45   0.64  -1.43  -0.78   0.03   0.04   0.07      2  71.97
# al_sig           0.32    0.13   0.23 3.5e-3   0.09   0.33   0.46   0.79      3   2.32
# alA              0.01  4.4e-3 7.1e-3-1.1e-5-1.1e-5   0.01   0.02   0.02      3   2.22
# alB             -0.76    1.27    1.8  -3.88  -2.09   0.23    0.3   0.43      2  34.56
# A[1]             0.05    0.02   0.03 9.5e-5   0.01   0.06   0.07   0.08      2    3.0
# A[2]             0.11    0.05   0.0710.0e-5   0.04   0.14   0.18   0.18      2  69.95
# A[3]           7.3e-3  3.0e-3 5.3e-3 1.0e-4 4.6e-4 7.9e-3   0.01   0.02      3   1.77
# A[4]             0.01  4.3e-3 6.7e-3 9.9e-5 1.5e-3   0.01   0.02   0.02      2   2.69
# A[5]             0.02  7.6e-3   0.01 1.0e-4 4.3e-4   0.02   0.03   0.03      3    2.4
# G[1]             3.88    0.37   0.59    3.0   3.17    4.0    4.3   4.83      3   2.32
# G[2]             4.52    1.17   1.66   2.62   2.85   4.61   6.17   6.21      2  116.7
# G[3]             3.48    0.14   0.49   2.79   3.06   3.38   3.82   4.59     12   1.33
# G[4]             3.29    0.05   0.21   2.95   3.17   3.22   3.42   3.79     19   1.23
# G[5]             3.16    0.03   0.17    2.9   3.08    3.1   3.22   3.51     27   1.11
# phi[1]          -1.31    2.29   3.27  -5.47  -4.53  -0.73   1.72   2.82      2   7.48
# phi[2]          -0.58    1.19   1.69  -3.13  -1.77  -0.58   0.76    1.8      2  29.75
# phi[3]           2.79    1.81    2.6  -1.67   1.06   1.74   5.26    5.9      2    5.8
# phi[4]           -0.8    1.04    1.5  -2.35  -1.78  -1.46    0.8   1.73      2   5.81
# phi[5]            1.5    1.76   2.51  -0.98  -0.72   1.72   3.64   5.68      2   7.72
# tau[1]           53.6   53.65  75.88   9.45   9.72   9.87 106.47 185.06      2 530.59
# tau[2]         225.87   34.63  49.11 146.49  183.3 237.94 257.56  288.0      2  13.99
# tau[3]         168.43   24.18  34.34 139.86 147.55 150.43 198.31 227.61      2   11.4
# tau[4]         164.82   27.72  39.38 134.76 140.15 143.77 200.54 232.83      2  12.47
# tau[5]         207.36   67.04  94.89 144.91  150.7 154.43  279.0 371.77      2  27.33
# epsilon[1]        3.7    1.62   2.29  -0.27   1.93   4.97   5.07   5.25      2  24.47
# epsilon[2]       -1.1    0.06   0.09  -1.31  -1.16  -1.07   -1.0   -1.0      2   3.29
# epsilon[3]      -0.53    0.04   0.06  -0.62  -0.58  -0.55  -0.46  -0.44      2   2.81
# epsilon[4]      -0.45    0.03   0.05  -0.51  -0.51  -0.46  -0.42  -0.36      3   2.26
# epsilon[5]      -0.58    0.12   0.16  -0.87  -0.73   -0.5  -0.48  -0.46      2  11.68
# alpha[1]         0.65    0.27   0.38-9.4e-3   0.34   0.86   0.88   0.93      2  16.95
# alpha[2]        -0.07  9.9e-3   0.01  -0.09  -0.08  -0.08  -0.06  -0.05      2  35.06
# alpha[3]         0.02    0.01   0.02  -0.01 2.6e-3   0.02   0.03   0.03      2  18.65
# alpha[4]         0.02    0.01   0.02  -0.01 3.9e-3   0.03   0.03   0.03      2   21.6
# alpha[5]       6.7e-3    0.02   0.03  -0.04  -0.01   0.02   0.02   0.02      2  36.18
# lp__           -1.7e4  7609.9  1.1e4 -3.3e4 -2.8e4 -1.4e4  -7283  -7276      2 1611.9
#
# Samples were drawn using NUTS at Mon Mar 11 17:12:25 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
def model(n, dnu, numax, epsilon, alpha, A, G, phi, tau):
    nmax = numax/dnu - epsilon
    freqs = (n + epsilon + (alpha/2) * (n - nmax)**2 + ((A*G)/(2*np.pi)) * np.sin((2*np.pi*(n-nmax))/G + phi)) * dnu# * np.exp(-n/tau)
    return freqs

# %%
#for i in range(len(IDs)):
    #print(np.mean(modesID[i]['dnu']))

#for i in range(len(IDs)):
    #print(np.mean(fit['G'], axis=0)[i])

# %%
# %matplotlib inline
    
for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    plt.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    plt.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], np.mean(fit['tau'], axis=0)[i]) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(g2 % dnu_avgID[i], g2, label='Fit_2D', c=colour)


#Plot stan fitted model on echelle
#for i in range(len(IDs)):
    #plt.figure(len(IDs))
    #plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    #g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          #np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    #plt.plot(g2 % np.mean(fit['dnu'],axis=0)[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Mod. Freq. Spacing ($\mu Hz$)')
plt.xlim(-1,5)
plt.show()

# %%
#Plot stan fitted model for freq vs n
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(arr_n[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Radial mode')
plt.show()

# %%
#Plot stan deduced parameters against dnu
dnus = []
numaxs = []
epsilons = []
alphas = []
As = []
Gs = []
phis = []
taus = []
for i in range(len(IDs)):
    dnus.append(np.mean(fit['dnu'],axis=0)[i])
    numaxs.append(np.mean(fit['dnu'],axis=0)[i])
    epsilons.append(np.mean(fit['epsilon'],axis=0)[i])
    alphas.append(np.mean(fit['alpha'],axis=0)[i])
    As.append(np.mean(fit['A'],axis=0)[i])
    Gs.append(np.mean(fit['G'],axis=0)[i])
    phis.append(np.mean(fit['phi'],axis=0)[i])
    taus.append(np.mean(fit['tau'],axis=0)[i])
    
fig, axs = plt.subplots(2, 3, figsize=(15, 8), sharey=False, sharex=False)
axs[0,0].scatter(dnus, epsilons)
axs[0,0].set_title(r'$\epsilon$')
axs[1,0].scatter(dnus, alphas)
axs[1,0].set_title(r'$\alpha$')
axs[0,1].scatter(dnus, As)
axs[0,1].set_title(r'$\mathcal{A}$')
axs[1,1].scatter(dnus, Gs)
axs[1,1].set_title(r'$\mathcal{G}$')
axs[0,2].scatter(dnus, phis)
axs[0,2].set_title(r'$\phi$')
axs[1,2].scatter(dnus, taus)
axs[1,2].set_title(r'$\tau$')
fig.suptitle(r'Parameters plotted against $\langle \Delta \nu \rangle$')
# Out:
# Text(0.5, 0.98, 'Parameters plotted against $\\langle \\Delta \\nu \\rangle$')

# %%
plt.scatter(numaxs, Gs)
plt.xlabel(r'$\nu_{max} (\mu Hz)$')
plt.ylabel(r'$\mathcal{G}$ ($\mu Hz$)')
plt.title(r'Period vs frequency of max power ($\nu_{max}$)')
# Out:
# Text(0.5, 1.0, 'Period vs frequency of max power ($\\nu_{max}$)')

# %%
#Plot glitch amplitude against metallicity from APOKASC catalogue
df_met = pd.read_csv('../data/APOKASCfull.csv')
#metals = [(df_met.loc[(df_met['KIC'] == IDs[i])]).loc['[M/H]2'] for i in range(len(IDs))]


#metals = df_met.loc[(df_met['KIC'].isin(IDs))].reset_index(drop=True)

frames = []
for i in range(len(IDs)):
    mets = df_met.loc[df_met['KIC'] == IDs[i]]
    frames.append(mets)

metsall = pd.concat(frames).reset_index(drop=True)

IDdf = pd.DataFrame(IDs)
#ind = IDdf[~IDdf.isin(metsall['KIC'])]

#print(ind)
#print(metsall['KIC'])
#print(IDs)

plt.scatter(metsall['[M/H]2'].values, As)
#plt.xlabel('Metallicity')
#plt.ylabel('Glitch amplitude ($\mu Hz$)')
