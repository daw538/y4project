# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan
import os
import seaborn as sns

from IPython.display import display

from matplotlib import rc
rc("font", family="serif", size=11)

import itertools
colours = itertools.cycle(('r', 'b', 'g', 'orange', 'purple', 'k'))

# %matplotlib notebook

# %%
#Import output data
output = pd.read_csv('../data/cluster/NGC6819/output_NGC6819.csv', usecols=[1,2,3])
#IDs = [(output.loc[output['ID'] == random.choice(output['ID'])]).iloc[0]['Numax'] for i in range(5)]
df_met = pd.read_csv('../data/APOKASCfull.csv')
df_class = pd.read_csv('../data/RGclassification.txt', header=None, delim_whitespace=True, names=['KIC', 'type'])

#Set numax range so stars are chosen with similar size echelles
rng = 30
numax_tgt = 75
#output = output.loc[(np.abs(output['Numax'] - numax_tgt) < rng)].reset_index(drop=True)

#Number of stars to model (between 1 and 1212) and star classification (RGB, RC, 2CL)
#nStars = len(output['ID'])
nStars = 10
RGclass = 'RGB'

#IDs = output['ID'].values

IDs = [np.random.choice(output['ID'], replace=False) for i in range(nStars)]
#Add the Elsworth classification

#Chooses specific stars each time
#IDs = [8759811, 10416550, 8824452, 11821439, 9470276]

# Create a list of the numax values and errors corresponding to each ID
Numax = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax_err'] for i in range(len(IDs))]

print(IDs)
print(len(IDs))
# Out:
# [5112948, 5112744, 5023889, 5111718, 5024272, 5024312, 5023845, 5024297, 5024043, 5024582]
# 10

# %%
#Create acyclic graph (probabalistic graphical model)
from matplotlib import rc
rc("font", family="serif", size=16)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("AA", r"$AA_{RGB}$", 1.0, 2.6))
pgm.add_node(daft.Node("AB", r"$AB_{RGB}$", 2.0, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("A_true", r"$A_{{\rm true},i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("A_obs", r"$A_{{\rm obs},i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("Aerr", r"$\sigma_{A_{{\rm obs},i}}$", 0.4, 0.8, fixed=True, offset=[0.0,0.4]))
# Add in the edges.
pgm.add_edge("AA", "A_true")
pgm.add_edge("AB", "A_true")
pgm.add_edge("A_obs", "A_true")
pgm.add_edge("Aerr", "A_obs")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.4, 2.7, 1.7], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()

# %%
#Import mode data and construct arrays for storing orders and frequencies
modesID = [pd.read_csv('../data/cluster/NGC6819/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0']) for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])

#Sort values by frequency and assign order and calculate avg dnu
dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    #(due to some stars having fewer mode frequencies observed)
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            #modesID[i].loc[l] = [l, int(np.max(modesID[i]['n']+l)), (np.max(modesID[i]['dnu'])+dnu_avgID[i]), np.nan , 10000]
            #app = pd.DataFrame([(np.max(modesID[i]['dnu'])+dnu_avgID[i]), 10000], columns=['n', 'f0', 'f0_err'])
            #modesID[i].append(app, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
dnu_avgarr = np.asarray(dnu_avgID)

# %%
#Construct and plot echelles for each star
for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    plt.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    plt.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)

#for i in np.arange(0,len(IDs),1):
    #plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
numax_err = Numax_err
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
#A = np.ones([len(IDs)])*0.05 
A = 0.6*dnu_avgarr**(-0.88)
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*1000
phi = np.ones([len(IDs)])*1.71

plt.ylabel('Frequency')
plt.xlabel(r'Frequency modulo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()
#print(A)

# %%
# First run with no decay term
code = '''
functions{
    real asex(real n, real dnu, real numax, real epsilon, real alpha, real A, real G, real phi){
        real nmax = numax/dnu - epsilon;
        return (n + epsilon + (alpha/2) * (nmax - n)^2 + 
                A*G/(2*pi()) * sin((2*pi()*(n-nmax))/G + phi))*dnu;
    }
}
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M];
    real freq[N, M];
    real freq_err[N, M];
    real dnu_guess[N];
    real numax_obs[N];
    real numax_err[N];
}
parameters {
    // Normal Parameters
    real dnu[N];
    real<lower = 0> numax[N];
    real <lower = 0> G[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N]; 
    
    //Hierarchical parameters
    real epsilon_std[N];
    real eps_sig;
    real epsA;
    real epsB;
    
    real alpha_std[N];
    real<lower = 0> al_sig;
    real alA;
    real alB;
    
    //real <lower = 0> A[N];
    real A_std[N];
    real<lower = 0> A_sig;
    real<lower = 0> AA;
    real<lower = 0> AB;
    
    //real G_std[N];
    //real<lower = 0> G_sig;
    //real GA;
    //real GB;
      
}

transformed parameters{
    real epsilon[N];
    real alpha[N];
    real A[N];
    //real G[N];
    for (i in 1:N){
        epsilon[i] = epsilon_std[i] * eps_sig + (epsA + epsB * log(dnu[i]));
        alpha[i] = alpha_std[i] * al_sig + (alA * (dnu[i])^(-alB));
        A[i] = A_std[i] * A_sig + (AA*dnu[i]^(-AB));
        //G[i] = G_std[i] * G_sig + (GA*dnu[i]^(-GB));
    }
}
model {
    real mod[M];
    for (i in 1:N){
        for (j in 1:M){
            mod[j] = asex(n[i,j], dnu[i], numax[i], epsilon[i], alpha[i], A[i], G[i], phi[i]);
            //mod[j] ~ normal(freq[i], freq_err[i]);
        }
        freq[i,:] ~ normal(mod, freq_err[i,:]);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.1);
        numax[i] ~ normal(numax_obs[i], numax_err[i]);
        //dnu[i] ~ uniform(0, 20);
        
        //epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        //alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
        //A[i] ~ lognormal(log(AA*dnu[i]^(-AB)), 0.4);
        //epsilon[i] ~ uniform(-0.0, 2.0);
        //alpha[i] ~ lognormal(log(0.015*dnu[i]^(-0.32)), 0.5);
        //A[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.4);
    }
    G ~ normal(3.08, 0.65);
    //numax ~ normal(numax_obs, numax_err);
    
    //Hyperpriors
    epsilon_std ~ normal(0, 1);
    eps_sig ~ normal(0, 0.5);
    epsA ~ normal(0.601, 0.25);
    epsB ~ normal(0.632, 0.25);
    
    alpha_std ~ normal(0, 1);
    al_sig ~ normal(0, 0.5); 
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    
    A_std ~ student_t(5, 0, 1);
    A_sig ~ normal(0, 0.5);
    AA ~ normal(0.06, 0.02);
    AB ~ normal(0.88, 0.05);
    
    //G_std ~ normal(0, 1);
    //G_sig ~ normal(0, 0.5);
    //GA ~ normal(0.75, 0.1);
    //GB ~ normal(0.75, 0.1);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_8cd859fc745600cbd65bcdeefdbd3f6b NOW.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/2_/b8v0t8pn1hj1p3r4lyfvvv2h0000gn/T/tmp_zyodmqp/stanfit4anon_model_8cd859fc745600cbd65bcdeefdbd3f6b_552375707763748800.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr,
         'numax_obs': numax_obs,
         'numax_err': numax_err
        }
start = {'dnu': dnu_avgarr,
         'nmax': nmax,
         'numax': numax_obs,
         'epsilon': epsilon,
         'alpha': alpha,
         'A': A,
         'eps_sig': 0.001,
         'al_sig': 0.01,
         'A_sig': 0.0001,
         'G': G,
         'phi': phi,
         'epsA': 0.601,
         'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
         'AA': 0.06,
         'AB': 0.88
    }
nchains = 4

notau = sm.sampling(data=stan_data, iter=2000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter phi[8] is 0.0006107823509207869!
# WARNING:pystan:n_eff / iter for parameter phi[9] is 0.000963321500714419!
# WARNING:pystan:n_eff / iter for parameter phi[10] is 0.0005272588416022672!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[1] is 0.0006801006281833011!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[2] is 0.0006039609267508869!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[4] is 0.0008975754660329364!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[5] is 0.0005768148174137069!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[8] is 0.0006561526532229844!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[9] is 0.0009592359915595589!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[10] is 0.0005917848079492641!
# WARNING:pystan:n_eff / iter for parameter eps_sig is 0.0005908342335533742!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[8] is 1.1412164275458268!
# WARNING:pystan:Rhat for parameter dnu[10] is 1.1603796890343259!
# WARNING:pystan:Rhat for parameter numax[8] is 1.139454229342472!
# WARNING:pystan:Rhat for parameter numax[10] is 1.1970414192320609!
# WARNING:pystan:Rhat for parameter phi[2] is 1.9966712188215208!
# WARNING:pystan:Rhat for parameter phi[8] is 4.146619175662797!
# WARNING:pystan:Rhat for parameter phi[9] is 2.323405421567691!
# WARNING:pystan:Rhat for parameter phi[10] is 4.413176790772898!
# WARNING:pystan:Rhat for parameter epsilon_std[1] is 1.9650532339844344!
# WARNING:pystan:Rhat for parameter epsilon_std[2] is 2.4566227541770878!
# WARNING:pystan:Rhat for parameter epsilon_std[3] is 1.1559025441831852!
# WARNING:pystan:Rhat for parameter epsilon_std[4] is 1.5368637190685357!
# WARNING:pystan:Rhat for parameter epsilon_std[5] is 2.7365580690770526!
# WARNING:pystan:Rhat for parameter epsilon_std[8] is 2.0955689251364613!
# WARNING:pystan:Rhat for parameter epsilon_std[9] is 1.4846580644594314!
# WARNING:pystan:Rhat for parameter epsilon_std[10] is 2.5741848324386454!
# WARNING:pystan:Rhat for parameter eps_sig is 2.5938582172345486!
# WARNING:pystan:Rhat for parameter epsilon[8] is 1.1396801136243648!
# WARNING:pystan:Rhat for parameter epsilon[10] is 1.163639283837084!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:4000 of 4000 iterations saturated the maximum tree depth of 10 (100.0%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
print(notau)
# Out:
# Inference for Stan model: anon_model_8cd859fc745600cbd65bcdeefdbd3f6b.
# 4 chains, each with iter=2000; warmup=1000; thin=1;
# post-warmup draws per chain=1000, total post-warmup draws=4000.
#
#                   mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]            4.24  4.1e-4 8.6e-3   4.23   4.24   4.24   4.25   4.26    453   1.01
# dnu[2]            4.39  4.4e-4   0.01   4.36   4.38   4.39   4.39   4.41    577   1.01
# dnu[3]            5.33  1.6e-3   0.02   5.28   5.31   5.33   5.34   5.37    203   1.04
# dnu[4]           10.56  4.9e-4   0.01  10.53  10.55  10.56  10.56  10.58    545    1.0
# dnu[5]            2.03  1.4e-3   0.02    2.0   2.01   2.03   2.04   2.07    182   1.01
# dnu[6]            8.09  2.6e-3   0.04   8.01   8.07   8.09   8.12   8.18    252   1.01
# dnu[7]            8.94  3.9e-3   0.06   8.82    8.9   8.94   8.98   9.05    210   1.01
# dnu[8]            4.55  4.2e-3   0.02    4.5   4.53   4.55   4.56   4.59     30   1.14
# dnu[9]            5.58  1.5e-3   0.02   5.54   5.57   5.58    5.6   5.63    238   1.03
# dnu[10]           4.73  6.6e-3   0.02   4.69   4.72   4.73   4.75   4.78     12   1.16
# numax[1]          41.4    0.01   0.34  40.73  41.17   41.4  41.64  42.08    589   1.01
# numax[2]         42.52    0.02   0.41  41.71  42.26  42.53   42.8  43.31    516   1.01
# numax[3]         52.62    0.13   1.81   49.0  51.38  52.66  53.82  56.21    202   1.04
# numax[4]        134.51  7.1e-3    0.3 133.92  134.3 134.51 134.72  135.1   1792    1.0
# numax[5]         19.68    0.08   1.03  18.18  18.93  19.52  20.23  22.16    177   1.01
# numax[6]         95.59    0.25   3.92  88.16  92.87  95.43  98.38 103.18    250   1.01
# numax[7]        109.64    0.35   5.07  99.38 106.27 109.88 113.01 119.39    206   1.01
# numax[8]          45.0    0.28   1.55  41.95  43.92   45.0  46.04  48.07     30   1.14
# numax[9]         55.03    0.11   1.72  51.74  53.85   55.0   56.2  58.49    239   1.03
# numax[10]         44.5    0.55   1.61   41.4  43.56  44.43  45.27  48.38      9    1.2
# G[1]              3.63    0.02   0.34   3.08   3.39   3.59   3.83   4.43    503    1.0
# G[2]              3.06    0.08   0.79   1.87   2.42   2.75   3.73   4.64    100   1.06
# G[3]              2.73  9.2e-3   0.22   2.32   2.59   2.73   2.86   3.23    573   1.01
# G[4]              2.61  9.1e-3    0.2   2.25   2.47    2.6   2.74   3.03    485    1.0
# G[5]              3.03    0.02   0.36   2.51   2.81   2.98    3.2   3.96    325   1.01
# G[6]              2.94  8.9e-3   0.21   2.57    2.8   2.92   3.07   3.41    575   1.01
# G[7]              3.85    0.01   0.31    3.3   3.63   3.83   4.05   4.48    745   1.01
# G[8]              2.82    0.02    0.4   1.72   2.63   2.83   3.05   3.56    348   1.01
# G[9]              2.61    0.02   0.35   2.11   2.39   2.56   2.77   3.47    265   1.01
# G[10]             3.18    0.01   0.33   2.67   2.96   3.14   3.36   3.96    491    1.0
# phi[1]            0.33  9.8e-3   0.24  -0.12   0.17   0.33   0.48    0.8    570    1.0
# phi[2]           -0.16    0.63   1.93  -5.39  -0.51   0.14   1.04    2.4      9    2.0
# phi[3]            1.97    0.06   0.86   0.26    1.4   1.97   2.52   3.67    211   1.03
# phi[4]            2.35  7.1e-3   0.19   1.99   2.22   2.34   2.47   2.75    738    1.0
# phi[5]           -4.87    0.08   1.07  -6.22  -5.69  -5.08  -4.31  -2.17    192   1.02
# phi[6]            2.11    0.07   1.05   0.09   1.37   2.08   2.86   4.18    251   1.01
# phi[7]            1.86    0.07   0.94  -0.02   1.24    1.9   2.48   3.69    207   1.01
# phi[8]            0.04    2.24    3.5  -5.93  -1.84   0.65   1.64   6.25      2   4.15
# phi[9]           -0.13     1.6   3.14  -5.49  -3.84   1.46   2.33   3.53      4   2.32
# phi[10]           4.34    1.66   2.41  -0.74    3.1   5.58   5.99   6.26      2   4.41
# epsilon_std[1]    0.01    0.41   0.68  -1.15  -0.55  -0.03   0.59   1.21      3   1.97
# epsilon_std[2]    0.03    0.56   0.87  -1.39  -0.74  -0.06   0.82    1.5      2   2.46
# epsilon_std[3]    0.01    0.13   0.44  -0.84  -0.29-7.8e-3   0.32   0.89     12   1.16
# epsilon_std[4]   -0.07    0.46   0.88  -1.76   -0.7  -0.05   0.57   1.56      4   1.54
# epsilon_std[5]   -0.04     1.3   1.97  -3.08  -1.85   0.03   1.77   3.13      2   2.74
# epsilon_std[6]   -0.04    0.04   0.54  -1.09  -0.41  -0.05   0.32    1.0    154   1.03
# epsilon_std[7]   -0.02    0.05   0.64   -1.3  -0.46  -0.03   0.43   1.22    151   1.05
# epsilon_std[8]   -0.02    0.51   0.82  -1.43  -0.71  -0.02   0.68   1.43      3    2.1
# epsilon_std[9]   -0.02    0.27   0.53  -0.96  -0.41  -0.05   0.37   1.03      4   1.48
# epsilon_std[10]  -0.05    0.68   1.04  -1.72  -0.98  -0.09   0.86   1.66      2   2.57
# eps_sig           0.01    0.12   0.19  -0.26  -0.15 2.3e-3   0.16   0.35      2   2.59
# epsA              0.31  8.2e-3   0.14   0.04   0.21   0.31    0.4   0.59    299   1.01
# epsB             -0.07  5.2e-3   0.08  -0.24  -0.13  -0.08  -0.02   0.09    268   1.01
# alpha_std[1]     -0.03    0.03   0.85  -1.72  -0.58 2.6e-3   0.55   1.64    923    1.0
# alpha_std[2]      0.08    0.03   0.86  -1.64  -0.51   0.08   0.63   1.74    828    1.0
# alpha_std[3]     -0.29    0.03   0.77  -1.82  -0.77  -0.28   0.18   1.28    567   1.01
# alpha_std[4]     -0.66    0.04   0.84  -2.33   -1.2  -0.66  -0.13   1.09    554    1.0
# alpha_std[5]     -0.41    0.04   0.95  -2.23  -1.04  -0.43   0.23   1.51    717    1.0
# alpha_std[6]      -0.2    0.03   0.77  -1.74  -0.68   -0.2   0.27   1.33    497   1.01
# alpha_std[7]      0.35    0.03   0.82  -1.31  -0.17   0.36   0.89   1.97    671   1.01
# alpha_std[8]      0.84    0.03   0.87  -0.98   0.29   0.88   1.43   2.47    626    1.0
# alpha_std[9]      0.35    0.04   0.82  -1.28  -0.18   0.35   0.88   1.95    533    1.0
# alpha_std[10]     0.19    0.03   0.89  -1.65  -0.39   0.21    0.8   1.87    832    1.0
# al_sig          1.4e-3  5.1e-5 1.0e-3 7.6e-5 6.7e-4 1.2e-3 1.9e-3 3.8e-3    407    1.0
# alA               0.02  9.9e-5 2.4e-3   0.02   0.02   0.02   0.02   0.02    597   1.01
# alB               0.29  2.6e-3   0.06   0.16   0.25   0.29   0.33   0.41    608   1.01
# A_std[1]         -0.23    0.03   0.69  -1.66  -0.63   -0.2   0.22   1.07    495   1.01
# A_std[2]         -0.23    0.09   1.11  -2.77  -0.82  -0.18   0.45   1.86    157   1.01
# A_std[3]         -0.42    0.03   0.69  -1.99  -0.82  -0.36   0.03   0.85    430    1.0
# A_std[4]          1.33    0.05   0.74   0.23   0.84   1.22   1.69   3.12    236   1.03
# A_std[5]          0.06    0.05   1.08  -2.29  -0.55   0.07   0.71   2.18    494    1.0
# A_std[6]          0.85    0.03   0.62  -0.32   0.44   0.81   1.21   2.22    467   1.02
# A_std[7]          1.05    0.03   0.55   0.22   0.67   0.97   1.33   2.39    340   1.01
# A_std[8]         -0.58    0.06   0.87  -2.69   -1.0  -0.47  -0.02   0.86    214   1.01
# A_std[9]         -0.16    0.05   1.02  -2.13  -0.76  -0.21   0.38    2.1    403   1.01
# A_std[10]         1.18    0.04   0.94  -0.45   0.54   1.08   1.75   3.24    624    1.0
# A_sig           7.7e-3  3.7e-4 3.7e-3 2.7e-3 5.2e-3 7.0e-3 9.4e-3   0.02    103   1.03
# AA                0.08  6.7e-4   0.01   0.05   0.07   0.08   0.09    0.1    372    1.0
# AB                0.86  2.0e-3   0.05   0.77   0.83   0.87    0.9   0.96    602    1.0
# epsilon[1]        0.11  9.2e-4   0.02   0.07   0.09   0.11   0.12   0.15    456   1.01
# epsilon[2]        0.07  9.4e-4   0.02   0.03   0.06   0.07   0.09   0.12    581   1.01
# epsilon[3]        0.15  2.9e-3   0.04   0.06   0.12   0.14   0.17   0.23    203   1.04
# epsilon[4]        0.22  6.1e-4   0.01   0.19   0.21   0.22   0.23   0.25    522    1.0
# epsilon[5]        0.54  6.8e-3   0.09   0.32   0.49   0.55    0.6   0.68    179   1.01
# epsilon[6]        0.16  3.9e-3   0.06   0.04   0.12   0.16    0.2   0.27    250   1.01
# epsilon[7]        0.17  5.4e-3   0.08   0.02   0.12   0.16   0.22   0.32    209   1.01
# epsilon[8]        0.08  9.0e-3   0.05  -0.02   0.05   0.08   0.11   0.18     30   1.14
# epsilon[9]        0.11  2.6e-3   0.04   0.03   0.09   0.12   0.14   0.19    238   1.03
# epsilon[10]       0.04    0.01   0.05  -0.06   0.02   0.04   0.07   0.13     12   1.16
# alpha[1]          0.01  3.4e-5 1.2e-3   0.01   0.01   0.01   0.01   0.02   1277    1.0
# alpha[2]          0.01  4.0e-5 1.3e-3   0.01   0.01   0.01   0.01   0.02   1018    1.0
# alpha[3]          0.01  2.0e-5 7.8e-4   0.01   0.01   0.01   0.01   0.01   1509    1.0
# alpha[4]        9.0e-3  6.4e-5 1.3e-3 6.2e-3 8.1e-3 9.1e-3 9.8e-3   0.01    396    1.0
# alpha[5]          0.02  9.0e-5 2.1e-3   0.01   0.01   0.02   0.02   0.02    549   1.01
# alpha[6]          0.01  2.9e-5 8.7e-4 8.8e-3 9.9e-3   0.01   0.01   0.01    900    1.0
# alpha[7]          0.01  4.4e-5 1.2e-3 9.1e-3   0.01   0.01   0.01   0.01    706   1.01
# alpha[8]          0.01  5.6e-5 1.4e-3   0.01   0.01   0.01   0.01   0.02    661    1.0
# alpha[9]          0.01  3.5e-5 1.1e-3   0.01   0.01   0.01   0.01   0.02   1063    1.0
# alpha[10]         0.01  4.0e-5 1.3e-3   0.01   0.01   0.01   0.01   0.02   1107   1.01
# A[1]              0.02  1.4e-4 4.1e-3   0.01   0.02   0.02   0.02   0.03    861    1.0
# A[2]              0.02  1.0e-3   0.01  -0.01   0.02   0.02   0.03   0.04    102   1.02
# A[3]              0.02  1.7e-4 4.4e-3 6.7e-3   0.01   0.02   0.02   0.02    681    1.0
# A[4]              0.02  1.4e-4 3.8e-3   0.01   0.02   0.02   0.02   0.03    740   1.01
# A[5]              0.04  4.0e-4 9.3e-3   0.02   0.04   0.04   0.05   0.06    525    1.0
# A[6]              0.02  1.7e-4 3.8e-3   0.01   0.02   0.02   0.02   0.03    510   1.01
# A[7]              0.02  5.2e-5 2.0e-3   0.01   0.02   0.02   0.02   0.02   1480    1.0
# A[8]              0.02  7.2e-4 6.8e-3 8.9e-4   0.01   0.02   0.02   0.03     90   1.03
# A[9]              0.02  3.4e-4 7.2e-3 3.1e-3   0.01   0.02   0.02   0.03    454    1.0
# A[10]             0.03  2.7e-4 6.6e-3   0.02   0.02   0.03   0.03   0.04    602   1.01
# lp__            -32.43    1.07   8.33 -48.71 -37.96 -32.36 -26.44 -17.26     61   1.06
#
# Samples were drawn using NUTS at Thu Mar 21 16:13:21 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
#2nd run with decay term
code = '''
functions{
    real asex(real n, real dnu, real numax, real epsilon, real alpha, real A, real G, real phi, real tau){
        real nmax = numax/dnu - epsilon;
        return (n + epsilon + (alpha/2) * (nmax - n)^2 + 
                A*G/(2*pi()) * sin((2*pi()*(n-nmax))/G + phi) * exp(-(n-nmax)/tau)) * dnu;
    }
}
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M];
    real freq[N, M];
    real freq_err[N, M];
    real dnu_guess[N];
    real numax_obs[N];
    real numax_err[N];
}
parameters {
    real dnu[N];
    real<lower = 0> numax[N];
    real <lower = 0> G[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N];
    real<lower = 0> tau[N];  
    
    //Hierarchical parameters
    real epsilon_std[N];
    real<lower = 0> eps_sig;
    real epsA;
    real epsB;
    
    real alpha_std[N];
    real<lower = 0> al_sig;
    real alA;
    real alB;
    
    //real <lower = 0> A[N];
    real A_std[N];
    real<lower = 0> A_sig;
    real<lower = 0> AA;
    real<lower = 0> AB;
    
    //real G_std[N];
    //real<lower = 0> G_sig;
    //real GA;
    //real GB;
      
}

transformed parameters{
    real epsilon[N];
    real alpha[N];
    real A[N];
    //real G[N];
    for (i in 1:N){
        epsilon[i] = epsilon_std[i] * eps_sig + (epsA + epsB * log(dnu[i]));
        alpha[i] = alpha_std[i] * al_sig + (alA * (dnu[i])^(-alB));
        A[i] = A_std[i] * A_sig + (AA*dnu[i]^(-AB));
        //G[i] = G_std[i] * G_sig + (GA*dnu[i]^(-GB));
    }
}
model {
    real mod[M];
    for (i in 1:N){
        for (j in 1:M){
            mod[j] = asex(n[i,j], dnu[i], numax[i], epsilon[i], alpha[i], A[i], G[i], phi[i], tau[i]);
            //mod[j] ~ normal(freq[i], freq_err[i]);
        }
        freq[i,:] ~ normal(mod, freq_err[i,:]);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.1);
        numax[i] ~ normal(numax_obs[i], numax_err[i]);
        //dnu[i] ~ uniform(0, 20);
        
        //epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        //alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
        //A[i] ~ lognormal(log(AA*dnu[i]^(-AB)), 0.4);
        //epsilon[i] ~ uniform(-0.0, 2.0);
        //alpha[i] ~ lognormal(log(0.015*dnu[i]^(-0.32)), 0.5);
        //A[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.4);
    }
    
    G ~ normal(3.08, 0.65);
    tau ~ normal(10, 5);
    //numax ~ normal(numax_obs, numax_err);
    //A ~ uniform(0,0.1);
    
    //Hyperpriors
    epsilon_std ~ normal(0, 1);
    eps_sig ~ normal(0, 0.5);
    epsA ~ normal(0.601, 0.25);
    epsB ~ normal(0.632, 0.25);
    
    alpha_std ~ normal(0, 1);
    al_sig ~ normal(0, 0.5); 
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    
    A_std ~ student_t(5, 0, 1);
    A_sig ~ normal(0, 0.5);
    AA ~ normal(0.06, 0.02);
    AB ~ normal(0.88, 0.05);
    
    //G_std ~ normal(0, 1);
    //G_sig ~ normal(0, 0.5);
    //GA ~ normal(0.75, 0.1);
    //GB ~ normal(0.75, 0.1);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_582a117f5c6d340d1be9c24e9169e462 NOW.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/2_/b8v0t8pn1hj1p3r4lyfvvv2h0000gn/T/tmpcq1e1kn1/stanfit4anon_model_582a117f5c6d340d1be9c24e9169e462_7076944652071100254.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr,
         'numax_obs': numax_obs,
         'numax_err': numax_err
        }
start = {'dnu': np.mean(notau['dnu'],axis=0)[:],
         'nmax': nmax,
         'numax': np.mean(notau['numax'],axis=0)[:],
         'epsilon': np.mean(notau['epsilon'],axis=0)[:],
         'alpha': np.mean(notau['alpha'],axis=0)[:],
         'A': (np.mean(notau['AA']))*(np.mean(notau['dnu'],axis=0)[:])**(np.mean(notau['AB'])), #np.mean(notau['A'],axis=0)[:],
         'eps_sig': 0.01,
         'al_sig': 0.01,
         'A_sig': 0.0001,
         'G': np.mean(notau['G'],axis=0)[:],
         'tau': tau,
         'phi': np.mean(notau['phi'],axis=0)[:],
         'epsA': np.mean(notau['epsA']),
         'epsB': np.mean(notau['epsB']),
         'alA': np.mean(notau['alA']),
         'alB': np.mean(notau['alB']),
         'AA': np.mean(notau['AA']),
         'AB': np.mean(notau['AB'])
    }
nchains = 4

fit = sm.sampling(data=stan_data, iter=8000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[7] is 0.00022592712682068642!
# WARNING:pystan:n_eff / iter for parameter numax[7] is 0.00021042213269262833!
# WARNING:pystan:n_eff / iter for parameter phi[3] is 0.0002687378651226581!
# WARNING:pystan:n_eff / iter for parameter phi[5] is 0.00015095381868085616!
# WARNING:pystan:n_eff / iter for parameter phi[7] is 0.00015354936040994945!
# WARNING:pystan:n_eff / iter for parameter phi[8] is 0.0008695038775602182!
# WARNING:pystan:n_eff / iter for parameter epsilon[7] is 0.00023147016704474073!
# WARNING:pystan:n_eff / iter for parameter A[7] is 0.00047883401449418155!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[7] is 1.5142704296375067!
# WARNING:pystan:Rhat for parameter numax[7] is 1.5839166814702583!
# WARNING:pystan:Rhat for parameter G[3] is 1.1455284413170055!
# WARNING:pystan:Rhat for parameter phi[2] is 1.1785924165083748!
# WARNING:pystan:Rhat for parameter phi[3] is 2.3550588549941316!
# WARNING:pystan:Rhat for parameter phi[5] is 2.3781785230548107!
# WARNING:pystan:Rhat for parameter phi[7] is 2.312073319439292!
# WARNING:pystan:Rhat for parameter phi[8] is 1.2614078943472888!
# WARNING:pystan:Rhat for parameter phi[9] is 1.1789225535192474!
# WARNING:pystan:Rhat for parameter epsilon[7] is 1.49443939559061!
# WARNING:pystan:Rhat for parameter A[7] is 1.1759422682788023!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:16000 of 16000 iterations saturated the maximum tree depth of 10 (100.0%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_582a117f5c6d340d1be9c24e9169e462.
# 4 chains, each with iter=8000; warmup=4000; thin=1;
# post-warmup draws per chain=4000, total post-warmup draws=16000.
#
#                   mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]            4.25  2.3e-4 8.5e-3   4.23   4.24   4.25   4.25   4.26   1337    1.0
# dnu[2]            4.39  2.7e-4   0.01   4.37   4.38   4.39   4.39   4.41   1518    1.0
# dnu[3]            5.33  8.0e-4   0.02   5.29   5.31   5.33   5.34   5.37    683   1.01
# dnu[4]           10.55  2.8e-4   0.01  10.53  10.54  10.55  10.56  10.57   1575    1.0
# dnu[5]            2.02  3.1e-3   0.02   1.98   2.01   2.02   2.03   2.06     39   1.07
# dnu[6]             8.1  1.6e-3   0.04   8.01   8.07    8.1   8.13   8.18    718    1.0
# dnu[7]            8.91    0.04   0.07   8.78   8.85   8.91   8.96   9.03      4   1.51
# dnu[8]            4.54  2.9e-3   0.02    4.5   4.53   4.54   4.56   4.59     62   1.05
# dnu[9]            5.58  6.6e-4   0.02   5.54   5.57   5.58    5.6   5.62    953    1.0
# dnu[10]           4.73  5.3e-4   0.02   4.69   4.72   4.73   4.74   4.76   1025    1.0
# numax[1]         41.42  8.8e-3   0.36  40.71  41.18  41.41  41.65  42.11   1663    1.0
# numax[2]         42.53  8.9e-3    0.4  41.75  42.27  42.53   42.8  43.31   1983    1.0
# numax[3]         52.49    0.07   1.77  49.03  51.29  52.49  53.65  55.99    674   1.01
# numax[4]        134.52  4.9e-3    0.3 133.93 134.31 134.52 134.72  135.1   3698    1.0
# numax[5]         19.08    0.27   1.26  16.36  18.39  19.11  19.84  21.59     22   1.09
# numax[6]         95.72    0.16   4.15  87.44  92.84  95.78  98.57 103.68    708    1.0
# numax[7]        107.22    3.73   6.85  95.23 100.44 108.12 112.38 119.44      3   1.58
# numax[8]         44.61     0.2   1.56  41.63  43.53  44.58   45.7  47.65     58   1.05
# numax[9]         54.97    0.05   1.57  51.92  53.89  54.96  56.04  58.08    917    1.0
# numax[10]        44.14    0.04   1.15   41.5  43.45  44.28  44.96   46.0    989    1.0
# G[1]              3.55  9.4e-3   0.36   2.96   3.31   3.52   3.76   4.35   1435    1.0
# G[2]              3.19    0.03   0.78   1.77   2.53   3.16   3.83   4.62    587   1.01
# G[3]              2.62    0.06   0.32   1.64   2.49   2.65    2.8   3.15     26   1.15
# G[4]              2.53    0.01   0.25   1.85    2.4   2.55   2.68   2.95    317   1.01
# G[5]              2.93    0.01   0.33    2.4   2.74    2.9   3.09   3.66   1024   1.01
# G[6]              2.94  3.1e-3   0.15   2.66   2.83   2.93   3.03   3.27   2415    1.0
# G[7]              3.72  8.4e-3   0.36   3.02   3.48   3.71   3.95   4.47   1879    1.0
# G[8]              2.79    0.02   0.42   1.65   2.61   2.82   3.03   3.56    774    1.0
# G[9]              2.55    0.05   0.44   1.61   2.35   2.54   2.77   3.47     79   1.04
# G[10]             3.21  7.5e-3   0.33   2.69   2.98   3.17   3.39   3.98   1923    1.0
# phi[1]             0.3  7.2e-3   0.27  -0.19   0.12   0.29   0.46   0.85   1395    1.0
# phi[2]            0.38    0.31   1.87  -5.13  -0.38   0.22   1.02    5.9     36   1.18
# phi[3]           -1.17    1.52   3.15  -5.68   -4.3  -0.77   1.85   3.28      4   2.36
# phi[4]            2.47    0.03   0.38   1.99   2.25    2.4   2.58    3.8    201   1.02
# phi[5]           -2.37    1.87   2.91  -6.16  -5.18  -2.69   0.23   2.79      2   2.38
# phi[6]            2.14    0.04   1.12  -0.08   1.37   2.15   2.89   4.29    711    1.0
# phi[7]            2.92    1.23   1.93   0.08   1.52   2.34   4.54   6.24      2   2.31
# phi[8]            0.34    0.93   3.47  -5.92  -0.76   0.59   1.72   6.19     14   1.26
# phi[9]           -0.87    0.67   3.47  -5.59  -4.23  -0.77    2.1   5.59     27   1.18
# phi[10]            5.7    0.01   0.46   4.55   5.43    5.8   6.06   6.26   1071    1.0
# tau[1]           10.87    0.09   4.33   3.35   7.69  10.63  13.74  19.93   2360    1.0
# tau[2]           10.37    0.08   4.48    2.5   7.05  10.17  13.42  19.55   2870    1.0
# tau[3]           10.62    0.08   4.34   3.47   7.29  10.26  13.51  19.87   2869    1.0
# tau[4]           10.16    0.09   4.47   2.72    6.8   9.92  13.15  19.58   2345    1.0
# tau[5]            12.2    0.08    4.2   4.79   9.15  11.99  14.99  20.93   2587    1.0
# tau[6]             7.4    0.08    4.1    2.2   4.11   6.49   9.86  17.22   2619    1.0
# tau[7]            7.01     0.1   3.91   2.14   3.99   6.02   9.25   16.5   1669    1.0
# tau[8]           10.45    0.09   4.58   2.48   7.07  10.22   13.6  19.93   2613    1.0
# tau[9]           10.36    0.09   4.55    2.5   6.99   10.1  13.41  19.85   2774    1.0
# tau[10]          10.52    0.08   4.42   3.09    7.2  10.27  13.43   19.8   2721    1.0
# epsilon_std[1]   -0.62    0.02   0.37  -1.36  -0.86  -0.61  -0.37   0.06    476    1.0
# epsilon_std[2]   -0.82    0.02   0.39  -1.65  -1.06   -0.8  -0.55  -0.12    520    1.0
# epsilon_std[3]   -0.25    0.02   0.39  -1.01  -0.49  -0.24   0.01    0.5    354   1.01
# epsilon_std[4]    0.63    0.06   0.61   -0.5    0.2   0.61   1.03   1.89    121   1.04
# epsilon_std[5]    1.86    0.02   0.73   0.52   1.37   1.83   2.33   3.38   1271    1.0
# epsilon_std[6]    0.05    0.02   0.53  -0.96  -0.31   0.04    0.4   1.13    565   1.01
# epsilon_std[7]     0.4    0.14   0.62  -0.76  -0.03   0.39   0.79   1.68     19    1.1
# epsilon_std[8]   -0.67    0.03   0.43  -1.56  -0.94  -0.65  -0.38   0.11    197   1.02
# epsilon_std[9]    -0.4    0.02   0.38  -1.17  -0.65  -0.39  -0.14    0.3    584    1.0
# epsilon_std[10]  -0.93    0.02   0.42  -1.85  -1.18   -0.9  -0.64  -0.17    511    1.0
# eps_sig           0.18  4.0e-3   0.06   0.09   0.14   0.17   0.21   0.32    221   1.04
# epsA              0.33  6.8e-3   0.16   0.02   0.22   0.33   0.44   0.65    539   1.01
# epsB             -0.08  4.2e-3   0.09  -0.27  -0.15  -0.09  -0.02    0.1    508   1.02
# alpha_std[1]     -0.03    0.02   0.82  -1.73  -0.54-1.3e-3   0.51   1.57   2124    1.0
# alpha_std[2]      0.08    0.02   0.88  -1.74  -0.48   0.09   0.66   1.78   2235    1.0
# alpha_std[3]    9.8e-3    0.02   0.72  -1.46  -0.42   0.02   0.45   1.41   1930    1.0
# alpha_std[4]     -0.63    0.02   0.84  -2.25  -1.17  -0.64  -0.12   1.15   1519    1.0
# alpha_std[5]     -0.52    0.02   0.97  -2.36  -1.18  -0.53   0.13   1.42   1974    1.0
# alpha_std[6]     -0.07    0.02   0.74  -1.61  -0.51  -0.06   0.38   1.37   1732    1.0
# alpha_std[7]     -0.11    0.02   0.86  -1.86  -0.67   -0.1   0.46   1.63   1611   1.01
# alpha_std[8]      1.03    0.02   0.87  -0.81   0.51   1.06   1.59   2.67   1664    1.0
# alpha_std[9]       0.6    0.02    0.8  -1.05   0.11   0.63   1.12   2.13   1828    1.0
# alpha_std[10]     0.06    0.02   0.88  -1.73   -0.5   0.08   0.64   1.75   2493    1.0
# al_sig          1.6e-3  3.5e-5 1.1e-3 7.3e-5 7.7e-4 1.4e-3 2.2e-3 4.3e-3   1057    1.0
# alA               0.02  5.8e-5 2.4e-3   0.01   0.02   0.02   0.02   0.02   1697    1.0
# alB                0.3  1.6e-3   0.07   0.16   0.25    0.3   0.34   0.43   1775    1.0
# A_std[1]         -0.34    0.02   0.77  -2.07  -0.77  -0.29   0.14   1.06   1404    1.0
# A_std[2]         -0.22    0.03   1.04  -2.39   -0.8  -0.21   0.38   1.83    937    1.0
# A_std[3]         -0.17    0.05   0.91   -2.2  -0.65  -0.14   0.35   1.59    347   1.01
# A_std[4]           1.1    0.02   0.72  -0.04   0.63    1.0   1.46   2.79    908   1.01
# A_std[5]          0.05    0.03   1.08  -2.12  -0.57   0.06   0.69   2.16   1791    1.0
# A_std[6]          0.84    0.02   0.73   -0.5    0.4   0.78   1.22   2.43   1293    1.0
# A_std[7]          0.74    0.11   0.62  -0.45   0.36    0.7   1.07    2.1     34   1.06
# A_std[8]         -0.54    0.03   0.89  -2.61  -1.01  -0.46 7.5e-3   1.01    698    1.0
# A_std[9]         -0.29    0.05   1.13  -2.82  -0.85  -0.22   0.35   1.78    536   1.01
# A_std[10]         1.17    0.02   1.01  -0.66   0.53    1.1   1.75   3.36   1959    1.0
# A_sig           7.3e-3  2.3e-4 4.4e-3 1.4e-3 4.5e-3 6.5e-3 9.2e-3   0.02    376   1.01
# AA                0.08  3.6e-4   0.01   0.05   0.07   0.08   0.08    0.1   1173    1.0
# AB                0.86  1.0e-3   0.05   0.76   0.83   0.86   0.89   0.96   2318    1.0
# epsilon[1]        0.11  5.3e-4   0.02   0.07   0.09   0.11   0.12   0.15   1349    1.0
# epsilon[2]        0.07  5.3e-4   0.02   0.03   0.06   0.07   0.09   0.12   1747    1.0
# epsilon[3]        0.15  1.5e-3   0.04   0.07   0.12   0.15   0.17   0.22    690   1.01
# epsilon[4]        0.23  3.6e-4   0.01    0.2   0.22   0.23   0.24   0.25   1506    1.0
# epsilon[5]        0.58    0.01   0.09   0.39   0.53   0.59   0.64   0.76     42   1.07
# epsilon[6]        0.16  2.3e-3   0.06   0.04   0.12   0.16    0.2   0.28    719    1.0
# epsilon[7]        0.21    0.05   0.09   0.04   0.14    0.2   0.29   0.37      4   1.49
# epsilon[8]        0.09  6.2e-3   0.05-4.7e-3   0.06   0.09   0.12   0.18     62   1.05
# epsilon[9]        0.12  1.2e-3   0.04   0.05   0.09   0.12   0.14   0.19    951    1.0
# epsilon[10]       0.05  1.0e-3   0.03  -0.01   0.02   0.04   0.07   0.12   1044    1.0
# alpha[1]          0.01  2.4e-5 1.3e-3 9.4e-3   0.01   0.01   0.01   0.01   3074    1.0
# alpha[2]          0.01  3.1e-5 1.5e-3 8.7e-3   0.01   0.01   0.01   0.02   2423    1.0
# alpha[3]          0.01  1.1e-5 7.9e-4 9.8e-3   0.01   0.01   0.01   0.01   5161    1.0
# alpha[4]        8.2e-3  3.7e-5 1.3e-3 5.4e-3 7.3e-3 8.3e-3 9.2e-3   0.01   1241    1.0
# alpha[5]          0.01  6.2e-5 2.4e-3 8.5e-3   0.01   0.01   0.02   0.02   1442   1.01
# alpha[6]       10.0e-3  1.5e-5 8.7e-4 8.2e-3 9.4e-310.0e-3   0.01   0.01   3409    1.0
# alpha[7]        9.5e-3  4.7e-5 1.5e-3 6.2e-3 8.8e-3 9.6e-3   0.01   0.01    999   1.01
# alpha[8]          0.01  3.9e-5 1.6e-3   0.01   0.01   0.01   0.01   0.02   1660    1.0
# alpha[9]          0.01  2.7e-5 1.3e-3   0.01   0.01   0.01   0.01   0.02   2233    1.0
# alpha[10]         0.01  2.8e-5 1.5e-3 8.6e-3   0.01   0.01   0.01   0.01   2909    1.0
# A[1]              0.02  7.7e-5 4.1e-3   0.01   0.02   0.02   0.02   0.03   2871    1.0
# A[2]              0.02  4.5e-4 9.0e-3-4.9e-3   0.02   0.02   0.02   0.04    403   1.01
# A[3]              0.02  5.4e-4 7.6e-3-8.5e-3   0.01   0.02   0.02   0.03    197   1.01
# A[4]              0.02  1.4e-4 3.9e-3   0.01   0.01   0.02   0.02   0.03    836   1.01
# A[5]              0.04  4.1e-4   0.01   0.02   0.04   0.04   0.05   0.06    645   1.01
# A[6]              0.02  9.8e-5 4.0e-3   0.01   0.02   0.02   0.02   0.03   1634    1.0
# A[7]              0.02  1.2e-3 3.2e-3   0.01   0.01   0.02   0.02   0.02      8   1.18
# A[8]              0.02  4.2e-4 7.3e-3-6.4e-3   0.01   0.02   0.02   0.03    300    1.0
# A[9]              0.02  4.5e-4 9.2e-3  -0.01   0.01   0.02   0.02   0.03    419   1.01
# A[10]             0.03  1.8e-4 6.8e-3   0.02   0.02   0.03   0.03   0.04   1344    1.0
# lp__            -12.97    0.32   8.57 -31.07  -18.4 -12.59  -6.99   2.67    703    1.0
#
# Samples were drawn using NUTS at Thu Mar 21 16:37:16 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fig = fit.plot()
fig.set_size_inches(18, 10)
fig.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/figure.py:448: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())

# %%
def model(n, dnu, numax, epsilon, alpha, A, G, phi, tau):
    nmax = numax/dnu - epsilon
    freqs = (n + epsilon + (alpha/2) * (n - nmax)**2 + ((A*G)/(2*np.pi)) * np.sin((2*np.pi*(n-nmax))/G + phi) * np.exp(-(n-nmax)/tau)) * dnu 
    return freqs

# %%
for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    plt.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    plt.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)
    g2 = model(arr_n[i], np.mean(notau['dnu'],axis=0)[i], np.mean(notau['numax'],axis=0)[i], np.mean(notau['epsilon'], axis=0)[i], np.mean(notau['alpha'], axis=0)[i],
          np.mean(notau['A'], axis=0)[i], np.mean(notau['G'], axis=0)[i], np.mean(notau['phi'], axis=0)[i], 10000)
    plt.plot(g2 % dnu_avgID[i], g2, label='Fit_2D', c=colour)

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Mod. Freq. Spacing ($\mu Hz$)')
#plt.xlim(-1,5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

for i in np.arange(0,len(IDs),1):
    # Iterate point colour
    colour = next(colours)
    # Plot all frequencies, and errorbars for the 'true' data
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'],
                label='', zorder=-1, facecolors='none', edgecolors=colour)
    pts = modesID[i].loc[(modesID[i]['f0_err'] < 10e3)]
    plt.scatter(pts['f0'] % dnu_avgID[i], pts['f0'],
                label=r'ID = '+str(IDs[i]), c=colour)
    plt.errorbar(pts['f0'] % dnu_avgID[i], pts['f0'], xerr=pts['f0_err'],
                        zorder=0, fmt="none", label='', c='k',
                        capsize=2, markersize=4, elinewidth=1)
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], np.mean(fit['tau'], axis=0)[i])
    plt.plot(g2 % dnu_avgID[i], g2, label='Fit_2D', c=colour) #np.mean(fit['dnu'],axis=0)[i],

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Mod. Freq. Spacing ($\mu Hz$)')
#plt.xlim(-1,5)
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
#Plot stan fitted model for freq vs n
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(arr_n[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Radial order')
plt.show()

# %%
#Plot stan deduced parameters against dnu
dnus = []
numaxs = []
epsilons = []
alphas = []
As = []
Gs = []
phis = []
taus = []
for i in range(len(IDs)):
    dnus.append(np.mean(fit['dnu'],axis=0)[i])
    numaxs.append(np.mean(fit['dnu'],axis=0)[i])
    epsilons.append(np.mean(fit['epsilon'],axis=0)[i])
    alphas.append(np.mean(fit['alpha'],axis=0)[i])
    As.append(np.mean(fit['A'],axis=0)[i])
    Gs.append(np.mean(fit['G'],axis=0)[i])
    phis.append(np.mean(fit['phi'],axis=0)[i])
    taus.append(np.mean(fit['tau'],axis=0)[i])
    
fig, axs = plt.subplots(2, 3, figsize=(9, 5), sharey=False, sharex=False)
axs[0,0].scatter(dnus, epsilons)
axs[0,0].plot(dnus, fit['epsA'].mean() + fit['epsB'].mean() * np.log(dnus), '.', c='r')
axs[0,0].set_title(r'$\epsilon$')
axs[1,0].scatter(dnus, alphas)
axs[1,0].plot(dnus, fit['alA'].mean() * (dnus)**(-fit['alB'].mean()), '.', c='r')
axs[1,0].set_title(r'$\alpha$')
axs[0,1].scatter(dnus, As)
axs[0,1].plot(dnus, fit['AA'].mean() * dnus ** (-fit['AB'].mean()), '.', c='r')
axs[0,1].set_title(r'$\mathcal{A}$')
axs[1,1].scatter(dnus, Gs)
axs[1,1].set_title(r'$\mathcal{G}$')
axs[0,2].scatter(dnus, phis)
axs[0,2].set_title(r'$\phi$')
axs[1,2].scatter(dnus, taus)
axs[1,2].set_title(r'$\tau$')
fig.suptitle(r'Parameters plotted against $\langle \Delta \nu \rangle$')
# Out:
# Text(0.5, 0.98, 'Parameters plotted against $\\langle \\Delta \\nu \\rangle$')

# %%
plt.scatter(numaxs, Gs)
plt.xlabel(r'$\nu_{max} (\mu Hz)$')
plt.ylabel(r'$\mathcal{G}$ ($\mu Hz$)')
plt.title(r'Period vs frequency of max power ($\nu_{max}$)')
# Out:
# Text(0.5, 1.0, 'Period vs frequency of max power ($\\nu_{max}$)')

# %%
sns.distplot(fit['A_sig'])
# Out:
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/scipy/stats/stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Plot glitch amplitude against metallicity from APOKASC catalogue
df_met = pd.read_csv('../data/APOKASCfull.csv')
#metals = [(df_met.loc[(df_met['KIC'] == IDs[i])]).loc['[M/H]2'] for i in range(len(IDs))]


#metals = df_met.loc[(df_met['KIC'].isin(IDs))].reset_index(drop=True)

frames = []
for i in range(len(IDs)):
    mets = df_met.loc[df_met['KIC'] == IDs[i]]
    frames.append(mets)

metsall = pd.concat(frames).reset_index(drop=True)

IDdf = pd.DataFrame(IDs)
#ind = IDdf[~IDdf.isin(metsall['KIC'])]

plt.scatter(metsall['[M/H]2'].values, As)
plt.xlabel('Metallicity')
plt.ylabel('Glitch amplitude ($\mu Hz$)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-395ea08c0713> in <module>
#      16 #ind = IDdf[~IDdf.isin(metsall['KIC'])]
#      17
# ---> 18 plt.scatter(metsall['[M/H]2'].values, As)
#      19 plt.xlabel('Metallicity')
#      20 plt.ylabel('Glitch amplitude ($\mu Hz$)')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2791         x=x, y=y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2792         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# -> 2793         verts=verts, edgecolors=edgecolors, data=data, **kwargs)
#    2794     sci(__ret)
#    2795     return __ret
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4163         y = np.ma.ravel(y)
#    4164         if x.size != y.size:
# -> 4165             raise ValueError("x and y must be the same size")
#    4166
#    4167         if s is None:
#
# ValueError: x and y must be the same size

# %%
fig, ax = plt.subplots(nStars)
for i in range(nStars):
    g = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i],
              np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
              np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i],
              np.mean(fit['phi'], axis=0)[i], np.mean(fit['tau'], axis=0)[i])
    ax[i].errorbar(arr_n[i, :], arr_freq[i,:] - g, yerr=arr_freqerr[i, :]*10, linestyle='none')
    ax[i].set_xlim([6,20])
    ax[i].set_ylim([-3.5, 3.5])
