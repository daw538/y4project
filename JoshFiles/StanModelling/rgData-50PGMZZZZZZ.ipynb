# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan

from IPython.display import display

from matplotlib import rc
rc("font", family="serif", size=11)

# %%
output = pd.read_csv('../data/output_1000stars.csv', usecols=range(1,4))
#IDs = [(output.loc[output['ID'] == random.choice(output['ID'])]).iloc[0]['Numax'] for i in range(5)]

noStars = 10
# Select a random sample of stars from the file, recording their IDs
IDs = [random.choice(output['ID']) for i in range(noStars)]
# Create a list of the numax values corresponding to each ID
Numax = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['ID'] == IDs[i])]).iloc[0]['Numax_err'] for i in range(len(IDs))]

print(IDs)
# Out:
# [10087394, 9941141, 9767332, 9596639, 11250139, 11191557, 11559818, 6104786, 11305250, 6188215]

# %%
# %matplotlib notebook
from matplotlib import rc
rc("font", family="serif", size=20)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("mu", r"$\mu$", 1.5, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("theta", r"$\theta_{i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("x", r"$x_{i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("xerr", r"$\sigma_{x_{i}}$", 0.4, 0.8, fixed=True, offset=[0.7,0.7]))
# Add in the edges.
pgm.add_edge("mu", "theta")
pgm.add_edge("x", "theta")
pgm.add_edge("xerr", "x")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.2, 2.7, 2.0], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()
# Out:
# <img src="data:image/png;base64,..." width="354">

# %%
# %matplotlib notebook
from matplotlib import rc
rc("font", family="serif", size=20)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("mu", r"$\mu$", 1.5, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("theta", r"$\theta_{i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("x", r"$x_{i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("xerr", r"$\sigma_{x_{i}}$", 0.4, 0.8, fixed=True, offset=[0.7,0.7]))
# Add in the edges.
pgm.add_edge("mu", "theta")
pgm.add_edge("x", "theta")
pgm.add_edge("xerr", "x")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.2, 2.7, 2.0], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()

# %%
from matplotlib import rc
rc("font", family="serif", size=16)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("AA", r"$AA_{RGB}$", 1.0, 2.6))
pgm.add_node(daft.Node("AB", r"$AB_{RGB}$", 2.0, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("A_true", r"$A_{{\rm true},i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("A_obs", r"$A_{{\rm obs},i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("Aerr", r"$\sigma_{A_{{\rm obs},i}}$", 0.4, 0.8, fixed=True, offset=[0.0,0.4]))
# Add in the edges.
pgm.add_edge("AA", "A_true")
pgm.add_edge("AB", "A_true")
pgm.add_edge("A_obs", "A_true")
pgm.add_edge("Aerr", "A_obs")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.4, 2.7, 1.7], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()

# %%
modesID = [pd.read_csv('../data/rgbmodes/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0'])
           for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])


dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            #modesID[i].loc[l] = [l, int(np.max(modesID[i]['n']+l)), (np.max(modesID[i]['dnu'])+dnu_avgID[i]), np.nan , 10000]
            #app = pd.DataFrame([(np.max(modesID[i]['dnu'])+dnu_avgID[i]), 10000], columns=['n', 'f0', 'f0_err'])
            #modesID[i].append(app, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
dnu_avgarr = np.asarray(dnu_avgID)

# %%
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
A = 0.06*dnu_avgarr**(-0.88) 
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*10
phi = np.ones([len(IDs)])*1.71

plt.ylabel('Frequency')
plt.xlabel(r'Frequency modulo')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %%
code = '''
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M];
    real freq[N, M];
    real freq_err[N, M];
    real dnu_guess[N];
    real nmax_guess[N];
}
parameters {
    real dnu[N];
    real nmax[N];
    real epsilon[N];
    real alpha[N];
    real<lower = 0> A[N];
    real<lower = 0> G[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N];
    real<lower = 0> tau[N];
    real epsA;
    real epsB;
    real alA;
    real alB;
    real AA;
    real AB;
    
}
model {
    real mod[M];
    for (i in 1:N){
        for (j in 1:M){
            mod[j] = (n[i,j] + epsilon[i] + (alpha[i]/2) * (nmax[i] - n[i,j])^2 + 
                A[i]*G[i]/(2*pi()) * sin((2*pi()*(n[i,j]-nmax[i]))/G[i] + phi[i]))*dnu[i];
                //*exp(-n[i,j]/tau[i]);
            mod[j] ~ normal(freq[i], freq_err[i]);
        }
        nmax[i] ~ normal(nmax_guess[i], nmax_guess[i]*0.1);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.01);
        epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
        A[i] ~ lognormal(log(AA*dnu[i]^(-AB)), 0.4);
        //epsilon[i] ~ uniform(-1.0, 2.0);
        //alpha[i] ~ lognormal(log(0.015*dnu[i]^(-0.32)), 0.5);
        //A[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.6);
    }
    nmax ~ normal(10, 4);
    G ~ normal(3.08, 0.65);
    tau ~ normal(20, 10);
    epsA ~ normal(0.601, 0.08);
    epsB ~ normal(0.632, 0.08);
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    AA ~ normal(0.06, 0.01);
    AB ~ normal(0.88, 0.05);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3 NOW.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/2_/b8v0t8pn1hj1p3r4lyfvvv2h0000gn/T/tmp786l3zg5/stanfit4anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3_6486327874378546150.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr,
         'nmax_guess': nmax
        }
start = {'dnu': dnu_avgarr,
         'nmax': nmax,
         'epsilon': epsilon,
         'alpha': alpha,
         'A': A,
         'G': G,
         'tau': tau,
         'phi': phi,
         'epsA': 0.601,
         'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
         'AA': 0.06,
         'AB': 0.88
    }
nchains = 4

fit = sm.sampling(data=stan_data, iter=20000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[1] is 0.00015627406418280632!
# WARNING:pystan:n_eff / iter for parameter dnu[2] is 0.00012175542555445635!
# WARNING:pystan:n_eff / iter for parameter dnu[3] is 0.00015374034043598743!
# WARNING:pystan:n_eff / iter for parameter dnu[4] is 0.00014300057680555805!
# WARNING:pystan:n_eff / iter for parameter dnu[5] is 0.00019142365792759465!
# WARNING:pystan:n_eff / iter for parameter dnu[6] is 0.0001583093565158147!
# WARNING:pystan:n_eff / iter for parameter dnu[7] is 0.00014426575179303598!
# WARNING:pystan:n_eff / iter for parameter dnu[8] is 0.00010603011148423475!
# WARNING:pystan:n_eff / iter for parameter dnu[9] is 0.00015018921622522306!
# WARNING:pystan:n_eff / iter for parameter dnu[10] is 0.0001428452456272795!
# WARNING:pystan:n_eff / iter for parameter nmax[1] is 0.0002441140648175617!
# WARNING:pystan:n_eff / iter for parameter nmax[2] is 0.0001941811837048006!
# WARNING:pystan:n_eff / iter for parameter nmax[3] is 5.571715756298937e-05!
# WARNING:pystan:n_eff / iter for parameter nmax[4] is 0.00010815774739267791!
# WARNING:pystan:n_eff / iter for parameter nmax[5] is 0.0001870948075069492!
# WARNING:pystan:n_eff / iter for parameter nmax[6] is 0.00011008531078281585!
# WARNING:pystan:n_eff / iter for parameter nmax[7] is 0.0001586366610068119!
# WARNING:pystan:n_eff / iter for parameter nmax[8] is 0.00016549674092765774!
# WARNING:pystan:n_eff / iter for parameter nmax[9] is 6.647113070164609e-05!
# WARNING:pystan:n_eff / iter for parameter nmax[10] is 0.00017102878202845695!
# WARNING:pystan:n_eff / iter for parameter epsilon[1] is 0.00013963162044579493!
# WARNING:pystan:n_eff / iter for parameter epsilon[2] is 0.00012308360496436776!
# WARNING:pystan:n_eff / iter for parameter epsilon[3] is 0.0001350610451004138!
# WARNING:pystan:n_eff / iter for parameter epsilon[4] is 0.0001766297464088532!
# WARNING:pystan:n_eff / iter for parameter epsilon[5] is 0.00014515233125828546!
# WARNING:pystan:n_eff / iter for parameter epsilon[6] is 0.00015953790745742535!
# WARNING:pystan:n_eff / iter for parameter epsilon[7] is 0.00026514878776101385!
# WARNING:pystan:n_eff / iter for parameter epsilon[8] is 0.00010334193597390316!
# WARNING:pystan:n_eff / iter for parameter epsilon[9] is 0.00016293735146602785!
# WARNING:pystan:n_eff / iter for parameter epsilon[10] is 0.00019358003047368778!
# WARNING:pystan:n_eff / iter for parameter alpha[1] is 0.0002507970256354856!
# WARNING:pystan:n_eff / iter for parameter alpha[2] is 0.00013339107571969254!
# WARNING:pystan:n_eff / iter for parameter alpha[3] is 0.0002316411603244128!
# WARNING:pystan:n_eff / iter for parameter alpha[4] is 0.00015743859475157403!
# WARNING:pystan:n_eff / iter for parameter alpha[5] is 0.00038267577868136577!
# WARNING:pystan:n_eff / iter for parameter alpha[6] is 0.00014868762852059575!
# WARNING:pystan:n_eff / iter for parameter alpha[7] is 0.00015902645924640923!
# WARNING:pystan:n_eff / iter for parameter alpha[8] is 0.00010900635475653839!
# WARNING:pystan:n_eff / iter for parameter alpha[9] is 0.0001460102210019749!
# WARNING:pystan:n_eff / iter for parameter alpha[10] is 0.00016621211150740625!
# WARNING:pystan:n_eff / iter for parameter A[1] is 7.23227090502968e-05!
# WARNING:pystan:n_eff / iter for parameter A[2] is 0.00017114340640685902!
# WARNING:pystan:n_eff / iter for parameter A[3] is 8.266960903181665e-05!
# WARNING:pystan:n_eff / iter for parameter A[4] is 0.00011921529098645709!
# WARNING:pystan:n_eff / iter for parameter A[5] is 0.00024235310270394854!
# WARNING:pystan:n_eff / iter for parameter A[6] is 5.9921038212834174e-05!
# WARNING:pystan:n_eff / iter for parameter A[7] is 7.413849605274359e-05!
# WARNING:pystan:n_eff / iter for parameter A[8] is 0.0001318813999062892!
# WARNING:pystan:n_eff / iter for parameter A[9] is 0.00022075810956764076!
# WARNING:pystan:n_eff / iter for parameter A[10] is 0.00014422350048052128!
# WARNING:pystan:n_eff / iter for parameter G[1] is 7.81591149589272e-05!
# WARNING:pystan:n_eff / iter for parameter G[2] is 0.00011594580262824154!
# WARNING:pystan:n_eff / iter for parameter G[3] is 0.00019327021324499756!
# WARNING:pystan:n_eff / iter for parameter G[4] is 0.00019865381296523048!
# WARNING:pystan:n_eff / iter for parameter G[5] is 0.000157551259125467!
# WARNING:pystan:n_eff / iter for parameter G[6] is 6.954239995070045e-05!
# WARNING:pystan:n_eff / iter for parameter G[7] is 0.0001907358153560454!
# WARNING:pystan:n_eff / iter for parameter G[8] is 0.00022344772688794254!
# WARNING:pystan:n_eff / iter for parameter G[9] is 7.698907117520991e-05!
# WARNING:pystan:n_eff / iter for parameter G[10] is 0.00033714670862471487!
# WARNING:pystan:n_eff / iter for parameter phi[1] is 0.00017138908752578917!
# WARNING:pystan:n_eff / iter for parameter phi[2] is 0.00015937002636515926!
# WARNING:pystan:n_eff / iter for parameter phi[3] is 7.126200168028362e-05!
# WARNING:pystan:n_eff / iter for parameter phi[4] is 0.00010008236420148589!
# WARNING:pystan:n_eff / iter for parameter phi[5] is 0.00016725044006920075!
# WARNING:pystan:n_eff / iter for parameter phi[6] is 0.00012729836054653019!
# WARNING:pystan:n_eff / iter for parameter phi[7] is 0.000101805263760792!
# WARNING:pystan:n_eff / iter for parameter phi[8] is 0.0001700891852215533!
# WARNING:pystan:n_eff / iter for parameter phi[9] is 0.00010588558669465138!
# WARNING:pystan:n_eff / iter for parameter phi[10] is 6.0902979495354136e-05!
# WARNING:pystan:n_eff / iter for parameter tau[1] is 0.00029473125098709326!
# WARNING:pystan:n_eff / iter for parameter tau[2] is 0.00013926320446588372!
# WARNING:pystan:n_eff / iter for parameter tau[3] is 0.0004493211699660147!
# WARNING:pystan:n_eff / iter for parameter tau[4] is 0.00014267839606311184!
# WARNING:pystan:n_eff / iter for parameter tau[5] is 8.763824325343897e-05!
# WARNING:pystan:n_eff / iter for parameter tau[6] is 8.70604956110789e-05!
# WARNING:pystan:n_eff / iter for parameter tau[7] is 0.00014947837857560512!
# WARNING:pystan:n_eff / iter for parameter tau[8] is 0.00013570209333441208!
# WARNING:pystan:n_eff / iter for parameter tau[9] is 0.000167042088492237!
# WARNING:pystan:n_eff / iter for parameter tau[10] is 0.00018776178161983084!
# WARNING:pystan:n_eff / iter for parameter epsA is 0.00018337382223906532!
# WARNING:pystan:n_eff / iter for parameter epsB is 8.719942097832053e-05!
# WARNING:pystan:n_eff / iter for parameter alA is 0.00017429344758235828!
# WARNING:pystan:n_eff / iter for parameter alB is 8.52449590177454e-05!
# WARNING:pystan:n_eff / iter for parameter AA is 0.00016096321602972929!
# WARNING:pystan:n_eff / iter for parameter AB is 0.0002825623474956434!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.00013684281137363766!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[1] is 1.8662174329324357!
# WARNING:pystan:Rhat for parameter dnu[2] is 2.4449870964728673!
# WARNING:pystan:Rhat for parameter dnu[3] is 1.8540845071577314!
# WARNING:pystan:Rhat for parameter dnu[4] is 2.5686828733399323!
# WARNING:pystan:Rhat for parameter dnu[5] is 1.5717472414269655!
# WARNING:pystan:Rhat for parameter dnu[6] is 1.7656243131831793!
# WARNING:pystan:Rhat for parameter dnu[7] is 2.3768649197666485!
# WARNING:pystan:Rhat for parameter dnu[8] is 2.1710240823077687!
# WARNING:pystan:Rhat for parameter dnu[9] is 1.823362331409425!
# WARNING:pystan:Rhat for parameter dnu[10] is 2.5756235038889335!
# WARNING:pystan:Rhat for parameter nmax[1] is 1.7725664387951872!
# WARNING:pystan:Rhat for parameter nmax[2] is 2.2381045374383453!
# WARNING:pystan:Rhat for parameter nmax[3] is 3.7747463718785226!
# WARNING:pystan:Rhat for parameter nmax[4] is 2.243758981430521!
# WARNING:pystan:Rhat for parameter nmax[5] is 2.0577062491447538!
# WARNING:pystan:Rhat for parameter nmax[6] is 2.4280886551617913!
# WARNING:pystan:Rhat for parameter nmax[7] is 1.8360860243105037!
# WARNING:pystan:Rhat for parameter nmax[8] is 1.8628071655219767!
# WARNING:pystan:Rhat for parameter nmax[9] is 2.9576104181500944!
# WARNING:pystan:Rhat for parameter nmax[10] is 1.9823026438147817!
# WARNING:pystan:Rhat for parameter epsilon[1] is 2.6603108971995613!
# WARNING:pystan:Rhat for parameter epsilon[2] is 2.6948381793000014!
# WARNING:pystan:Rhat for parameter epsilon[3] is 2.707230463189649!
# WARNING:pystan:Rhat for parameter epsilon[4] is 2.216307686759234!
# WARNING:pystan:Rhat for parameter epsilon[5] is 2.5941905749519414!
# WARNING:pystan:Rhat for parameter epsilon[6] is 2.3809755092517046!
# WARNING:pystan:Rhat for parameter epsilon[7] is 1.5821900503974944!
# WARNING:pystan:Rhat for parameter epsilon[8] is 2.6189416597553827!
# WARNING:pystan:Rhat for parameter epsilon[9] is 2.3363762697419297!
# WARNING:pystan:Rhat for parameter epsilon[10] is 1.9157607374814896!
# WARNING:pystan:Rhat for parameter alpha[1] is 1.347196641964114!
# WARNING:pystan:Rhat for parameter alpha[2] is 2.24251502594255!
# WARNING:pystan:Rhat for parameter alpha[3] is 1.4175298913572278!
# WARNING:pystan:Rhat for parameter alpha[4] is 2.305019886945997!
# WARNING:pystan:Rhat for parameter alpha[5] is 1.19378755683388!
# WARNING:pystan:Rhat for parameter alpha[6] is 1.6422828956902937!
# WARNING:pystan:Rhat for parameter alpha[7] is 2.1434373313787667!
# WARNING:pystan:Rhat for parameter alpha[8] is 2.532705859381021!
# WARNING:pystan:Rhat for parameter alpha[9] is 1.7005137894946087!
# WARNING:pystan:Rhat for parameter alpha[10] is 2.1566997205936143!
# WARNING:pystan:Rhat for parameter A[1] is 3.4999849245471664!
# WARNING:pystan:Rhat for parameter A[2] is 1.5480742470662803!
# WARNING:pystan:Rhat for parameter A[3] is 3.164673668755576!
# WARNING:pystan:Rhat for parameter A[4] is 3.6098536299543835!
# WARNING:pystan:Rhat for parameter A[5] is 1.8242803813167918!
# WARNING:pystan:Rhat for parameter A[6] is 3.2859682515223407!
# WARNING:pystan:Rhat for parameter A[7] is 2.1123054250341027!
# WARNING:pystan:Rhat for parameter A[8] is 2.2512009988875383!
# WARNING:pystan:Rhat for parameter A[9] is 1.4253579660135816!
# WARNING:pystan:Rhat for parameter A[10] is 2.3262819426923267!
# WARNING:pystan:Rhat for parameter G[1] is 2.960657699598028!
# WARNING:pystan:Rhat for parameter G[2] is 2.435566458917968!
# WARNING:pystan:Rhat for parameter G[3] is 1.8403644844492897!
# WARNING:pystan:Rhat for parameter G[4] is 2.042708444670512!
# WARNING:pystan:Rhat for parameter G[5] is 2.7739218814676474!
# WARNING:pystan:Rhat for parameter G[6] is 2.3374910557577784!
# WARNING:pystan:Rhat for parameter G[7] is 2.076446994264585!
# WARNING:pystan:Rhat for parameter G[8] is 2.327809162799319!
# WARNING:pystan:Rhat for parameter G[9] is 3.732974151730067!
# WARNING:pystan:Rhat for parameter G[10] is 1.6832998603573164!
# WARNING:pystan:Rhat for parameter phi[1] is 2.051553088618178!
# WARNING:pystan:Rhat for parameter phi[2] is 2.2784924557933612!
# WARNING:pystan:Rhat for parameter phi[3] is 2.2774912152964544!
# WARNING:pystan:Rhat for parameter phi[4] is 2.5484177301101294!
# WARNING:pystan:Rhat for parameter phi[5] is 2.387098129851323!
# WARNING:pystan:Rhat for parameter phi[6] is 2.1800888817496205!
# WARNING:pystan:Rhat for parameter phi[7] is 2.555310803455223!
# WARNING:pystan:Rhat for parameter phi[8] is 2.7410769213925015!
# WARNING:pystan:Rhat for parameter phi[9] is 2.3328377961753493!
# WARNING:pystan:Rhat for parameter phi[10] is 3.119384020882863!
# WARNING:pystan:Rhat for parameter tau[1] is 1.4914206663118186!
# WARNING:pystan:Rhat for parameter tau[2] is 1.7609972317029885!
# WARNING:pystan:Rhat for parameter tau[3] is 1.2948523838663188!
# WARNING:pystan:Rhat for parameter tau[4] is 1.73272579211765!
# WARNING:pystan:Rhat for parameter tau[5] is 2.243008628578424!
# WARNING:pystan:Rhat for parameter tau[6] is 3.0265839469038927!
# WARNING:pystan:Rhat for parameter tau[7] is 1.7504470774961742!
# WARNING:pystan:Rhat for parameter tau[8] is 2.0891372421920393!
# WARNING:pystan:Rhat for parameter tau[9] is 1.876308750228408!
# WARNING:pystan:Rhat for parameter tau[10] is 1.681676198564701!
# WARNING:pystan:Rhat for parameter epsA is 1.6304353820587856!
# WARNING:pystan:Rhat for parameter epsB is 1.797074913836496!
# WARNING:pystan:Rhat for parameter alA is 2.3108547522509117!
# WARNING:pystan:Rhat for parameter alB is 2.1546351532525154!
# WARNING:pystan:Rhat for parameter AA is 1.8328459438969977!
# WARNING:pystan:Rhat for parameter AB is 1.6560891959713682!
# WARNING:pystan:Rhat for parameter lp__ is 1.857886698945556!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:1 of 40000 iterations ended with a divergence (0.0025%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:82 of 40000 iterations saturated the maximum tree depth of 10 (0.205%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0003549245599762272
# WARNING:pystan:Chain 2: E-BFMI = 0.00031585989577059034
# WARNING:pystan:Chain 3: E-BFMI = 0.0005229984591302059
# WARNING:pystan:Chain 4: E-BFMI = 0.00021556821866635262
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3.
# 4 chains, each with iter=20000; warmup=10000; thin=1;
# post-warmup draws per chain=10000, total post-warmup draws=40000.
#
#               mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]        4.48    0.13   0.32   3.79   4.31   4.52   4.65   5.09      6   1.87
# dnu[2]         5.3    0.49   1.08   3.31    4.4   5.33   6.31   6.67      5   2.44
# dnu[3]        6.72     0.2    0.5    5.7   6.44   6.75   6.93   7.97      6   1.85
# dnu[4]        3.35    0.14   0.33    2.7   3.08   3.39   3.66   3.74      6   2.57
# dnu[5]        3.41    0.07   0.19   3.02   3.32   3.42   3.49   3.72      8   1.57
# dnu[6]        5.53    0.13   0.33   5.23   5.28   5.31   5.78    6.2      6   1.77
# dnu[7]        3.44    0.08    0.2   3.13   3.25   3.43   3.63    3.7      6   2.38
# dnu[8]        6.08    1.41    2.9   2.62   3.73   4.97   8.36  11.78      4   2.17
# dnu[9]        6.73    0.15   0.37   6.35   6.43   6.48   7.03   7.44      6   1.82
# dnu[10]       8.38    0.13   0.31   7.77   8.13   8.42   8.66   8.74      6   2.58
# nmax[1]       9.07  2.2e-5 6.8e-5   9.07   9.07   9.07   9.07   9.07     10   1.77
# nmax[2]       10.7  5.5e-5 1.5e-4   10.7   10.7   10.7   10.7   10.7      8   2.24
# nmax[3]      11.98  6.1e-5 9.2e-5  11.98  11.98  11.98  11.99  11.99      2   3.77
# nmax[4]       7.25  4.6e-5 9.6e-5   7.25   7.25   7.25   7.25   7.25      4   2.24
# nmax[5]       8.02  3.0e-5 8.2e-5   8.02   8.02   8.02   8.02   8.02      7   2.06
# nmax[6]      10.65  4.6e-5 9.7e-5  10.65  10.65  10.65  10.65  10.65      4   2.43
# nmax[7]       9.63  3.0e-5 7.7e-5   9.63   9.63   9.63   9.63   9.63      6   1.84
# nmax[8]      11.72  2.9e-5 7.6e-5  11.72  11.72  11.72  11.72  11.72      7   1.86
# nmax[9]      11.64  4.3e-5 7.1e-5  11.64  11.64  11.64  11.64  11.64      3   2.96
# nmax[10]     12.65  2.6e-5 6.9e-5  12.65  12.65  12.65  12.65  12.65      7   1.98
# epsilon[1]    1.25    0.33   0.79   0.53   0.61   0.99   1.64   3.51      6   2.66
# epsilon[2]     4.5    1.72   3.81   0.35   1.08   3.66   7.13  13.61      5   2.69
# epsilon[3]     1.6    0.39   0.91   0.79   0.87   1.27   2.06   4.23      5   2.71
# epsilon[4]    0.47  2.9e-3 7.7e-3   0.46   0.46   0.47   0.47   0.48      7   2.22
# epsilon[5]    0.81     0.2   0.49   0.37   0.42   0.65   1.04   2.24      6   2.59
# epsilon[6]    0.52    0.02   0.05   0.48   0.49    0.5   0.53   0.68      6   2.38
# epsilon[7]    0.43  7.9e-4 2.6e-3   0.42   0.42   0.42   0.43   0.43     11   1.58
# epsilon[8]   19.46     7.0  14.23   0.32   5.85  19.03  29.77  48.01      4   2.62
# epsilon[9]    0.67    0.02   0.06   0.62   0.63   0.65   0.68   0.87      7   2.34
# epsilon[10]    0.1  6.8e-3   0.02   0.07   0.08    0.1   0.12   0.13      8   1.92
# alpha[1]    1.7e-6  9.8e-8 3.1e-7 8.7e-7 1.5e-6 1.7e-6 1.8e-6 2.2e-6     10   1.35
# alpha[2]    1.6e-6  2.7e-7 6.3e-7 9.0e-7 1.1e-6 1.5e-6 2.0e-6 3.2e-6      5   2.24
# alpha[3]    1.6e-6  1.1e-7 3.5e-7 6.1e-7 1.5e-6 1.6e-6 1.8e-6 2.2e-6      9   1.42
# alpha[4]    3.6e-6  6.7e-7 1.7e-6 1.9e-6 2.3e-6 2.9e-6 4.4e-6 8.2e-6      6   2.31
# alpha[5]    1.9e-6  7.9e-8 3.1e-7 1.2e-6 1.8e-6 1.9e-6 2.1e-6 2.5e-6     15   1.19
# alpha[6]    2.8e-6  3.9e-7 9.5e-7 1.2e-6 1.9e-6 3.2e-6 3.6e-6 4.2e-6      6   1.64
# alpha[7]    5.4e-6  7.7e-7 2.0e-6 3.0e-6 3.7e-6 4.8e-6 6.9e-6 9.5e-6      6   2.14
# alpha[8]    3.1e-6  1.1e-6 2.2e-6 5.7e-7 1.1e-6 2.8e-6 4.5e-6 8.2e-6      4   2.53
# alpha[9]    2.4e-6  3.4e-7 8.1e-7 1.1e-6 1.6e-6 2.7e-6 3.1e-6 3.6e-6      6    1.7
# alpha[10]   6.0e-6  1.5e-6 3.8e-6 2.9e-6 3.5e-6 4.5e-6 7.1e-6 1.8e-5      7   2.16
# A[1]          0.01  1.0e-6 1.8e-6   0.01   0.01   0.01   0.01   0.01      3    3.5
# A[2]        9.7e-3  1.9e-7 5.0e-7 9.7e-3 9.7e-3 9.7e-3 9.7e-3 9.7e-3      7   1.55
# A[3]        9.0e-3  4.9e-7 8.8e-7 9.0e-3 9.0e-3 9.0e-3 9.0e-3 9.0e-3      3   3.16
# A[4]          0.02  9.3e-7 2.0e-6   0.02   0.02   0.02   0.02   0.02      5   3.61
# A[5]          0.02  4.6e-7 1.4e-6   0.02   0.02   0.02   0.02   0.02     10   1.82
# A[6]          0.01  8.3e-7 1.3e-6   0.01   0.01   0.01   0.01   0.01      2   3.29
# A[7]          0.02  9.7e-7 1.7e-6   0.02   0.02   0.02   0.02   0.02      3   2.11
# A[8]        5.9e-3  2.1e-7 4.7e-7 5.9e-3 5.9e-3 5.9e-3 5.9e-3 5.9e-3      5   2.25
# A[9]          0.01  1.9e-7 5.5e-7   0.01   0.01   0.01   0.01   0.01      9   1.43
# A[10]       8.9e-3  2.8e-7 6.8e-7 8.9e-3 8.9e-3 8.9e-3 8.9e-3 8.9e-3      6   2.33
# G[1]          3.08  1.5e-4 2.7e-4   3.08   3.08   3.08   3.08   3.08      3   2.96
# G[2]          3.08  2.2e-4 4.7e-4   3.08   3.08   3.08   3.08   3.08      5   2.44
# G[3]          3.08  7.9e-5 2.2e-4   3.08   3.08   3.08   3.08   3.08      8   1.84
# G[4]          3.08  1.4e-4 4.1e-4   3.08   3.08   3.08   3.08   3.08      8   2.04
# G[5]          3.08  1.8e-4 4.4e-4   3.08   3.08   3.08   3.08   3.08      6   2.77
# G[6]          3.08  1.7e-4 2.8e-4   3.08   3.08   3.08   3.08   3.08      3   2.34
# G[7]          3.08  6.0e-5 1.6e-4   3.08   3.08   3.08   3.08   3.08      8   2.08
# G[8]          3.08  7.1e-5 2.1e-4   3.08   3.08   3.08   3.08   3.08      9   2.33
# G[9]          3.08  2.4e-4 4.1e-4   3.08   3.08   3.08   3.08   3.08      3   3.73
# G[10]         3.08  3.6e-5 1.3e-4   3.08   3.08   3.08   3.08   3.08     13   1.68
# phi[1]        1.71  1.5e-4 3.9e-4   1.71   1.71   1.71   1.71   1.71      7   2.05
# phi[2]        1.71  2.6e-4 6.6e-4   1.71   1.71   1.71   1.71   1.71      6   2.28
# phi[3]        1.71  1.9e-4 3.2e-4   1.71   1.71   1.71   1.71   1.71      3   2.28
# phi[4]        1.71  1.4e-4 2.7e-4   1.71   1.71   1.71   1.71   1.71      4   2.55
# phi[5]        1.71  1.5e-4 3.9e-4   1.71   1.71   1.71   1.71   1.71      7   2.39
# phi[6]        1.71  1.1e-4 2.6e-4   1.71   1.71   1.71   1.71   1.71      5   2.18
# phi[7]        1.71  1.1e-4 2.2e-4   1.71   1.71   1.71   1.71   1.71      4   2.56
# phi[8]        1.71  1.0e-4 2.7e-4   1.71   1.71   1.71   1.71   1.71      7   2.74
# phi[9]        1.71  1.7e-4 3.4e-4   1.71   1.71   1.71   1.71   1.71      4   2.33
# phi[10]       1.71  1.7e-4 2.6e-4   1.71   1.71   1.71   1.71   1.71      2   3.12
# tau[1]        10.0  1.3e-4 4.4e-4   10.0   10.0   10.0   10.0   10.0     12   1.49
# tau[2]        10.0  2.5e-4 5.9e-4   10.0   10.0   10.0   10.0   10.0      6   1.76
# tau[3]        10.0  1.2e-4 5.1e-4   10.0   10.0   10.0   10.0   10.0     18   1.29
# tau[4]        10.0  1.9e-4 4.6e-4   10.0   10.0   10.0   10.0   10.0      6   1.73
# tau[5]        10.0  2.9e-4 5.5e-4   10.0   10.0   10.0   10.0   10.0      4   2.24
# tau[6]        10.0  5.6e-4 1.0e-3   10.0   10.0   10.0   10.0   10.0      3   3.03
# tau[7]        10.0  3.0e-4 7.2e-4   10.0   10.0   10.0   10.0   10.0      6   1.75
# tau[8]        10.0  2.5e-4 5.9e-4   10.0   10.0   10.0   10.0   10.0      5   2.09
# tau[9]        10.0  2.8e-4 7.3e-4   10.0   10.0   10.0   10.0   10.0      7   1.88
# tau[10]       10.0  1.8e-4 4.9e-4   10.0   10.0   10.0   10.0   10.0      8   1.68
# epsA           0.6  2.0e-5 5.5e-5    0.6    0.6    0.6    0.6    0.6      7   1.63
# epsB          0.63  4.7e-5 8.8e-5   0.63   0.63   0.63   0.63   0.63      3    1.8
# alA           0.01  6.8e-5 1.8e-4   0.01   0.01   0.01   0.01   0.01      7   2.31
# alB           0.32  3.2e-5 6.0e-5   0.32   0.32   0.32   0.32   0.32      3   2.15
# AA            0.06  2.4e-5 6.1e-5   0.06   0.06   0.06   0.06   0.06      6   1.83
# AB            0.88  1.5e-5 5.2e-5   0.88   0.88   0.88   0.88   0.88     11   1.66
# lp__        -2.5e8   2.5e7  6.0e7 -3.6e8 -2.8e8 -2.3e8 -2.0e8 -1.7e8      5   1.86
#
# Samples were drawn using NUTS at Mon Mar 11 16:57:55 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
def model(n, dnu, nmax, epsilon, alpha, A, G, phi, tau):
    freqs = (n + epsilon + (alpha/2) * (n - nmax)**2 + ((A*G)/(2*np.pi)) * np.sin((2*np.pi*(n-nmax))/G + phi)) * dnu# * np.exp(-n/tau)
    return freqs

# %%
#for i in range(len(IDs)):
    #print(np.mean(modesID[i]['dnu']))

#for i in range(len(IDs)):
    #print(np.mean(fit['G'], axis=0)[i])

# %%
# %matplotlib inline
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['nmax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(g2 % dnu_avgID[i], g2, label='Fit_2D')
    print(arr_freq[i])
    print(g2)

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Mod. Freq. Spacing ($\mu Hz$)')
plt.xlim(-2,7)
plt.show()
# Out:
# [42.82949557 48.41536046 54.31322765 60.29777173 66.20911982 72.47619861
#  78.40625641 84.33631421 90.26637201]
# [36.95685921 41.44136407 45.9625994  50.40393441 54.88075776 59.40543605
#  63.85140626 68.32066305 72.84760793]
# [ 65.82999266  73.31645537  81.25068442  89.20472862  97.14046153
#  105.22889296 113.47692054 121.43285709 129.38879364]
# [ 66.34121532  71.60537708  76.94122543  82.25725151  87.51950763
#   92.85014344  98.17285575 103.4343653  108.75906455]
# [ 87.2848518   95.57092719 104.16894645 112.7903092  121.29145262
#  129.98036518 139.04883939 147.41800077 156.05225586]
# [ 77.94110697  84.67372061  91.4317221   98.10486411 104.82935213
#  111.59231968 118.26919105 124.98543459 131.75221731]
# [25.42958182 29.09422025 32.86262781 36.56284945 40.47667006 44.22928964
#  47.98190921 51.73452878 55.48714836]
# [21.61308951 25.01000828 28.32385221 31.64624325 35.04400627 38.36502335
#  41.68018065 45.07742347 48.40624953]
# [28.18314556 32.52222842 37.05370361 41.64798552 46.28807995 50.97124027
#  55.54048355 60.10972682 64.6789701 ]
# [23.18881285 26.60477796 30.04791603 33.41505249 36.82369899 40.27086363
#  43.64173778 47.0430378  50.49315887]
# [ 50.7885765   56.80889461  62.82770543  69.20343918  75.42349339
#   81.72766358  88.06052253  94.4868884  100.73271672]
# [47.16761068 52.65261462 58.23165854 63.77465724 69.25623794 74.82941709
#  80.38127526 85.86084959 91.42711838]
# [29.42501248 32.83608236 36.53566144 40.21537645 43.86431664 47.53925088
#  51.39994934 55.45637871 59.17264814]
# [25.52684881 28.91506255 32.39565583 35.83790721 39.22248958 42.69759384
#  46.14859975 49.53091979 52.99947613]
# [129.04573447 142.50666205 156.37944088 170.08892377 184.0564069
#  198.13244682 211.96200397 225.79156112 239.62111827]
# [172.89964489 178.94600157 185.04238353 191.12691955 197.17218005
#  203.26480081 209.35399305 215.3989752  221.48735532]
# [ 68.78872942  75.81005321  83.20888439  90.79710933  98.31683109
#  105.72453208 113.48891221 120.97483168 128.46357845]
# [ 65.0561023   71.73198133  78.50534505  85.24060052  91.91285571
#   98.68019748 105.42466118 112.09475982 118.85498475]
# [ 80.46823829  88.91924708  97.3389485  106.20545404 114.85718377
#  123.41604168 132.0667455  141.25414554 150.66442832]
# [ 76.24686212  84.62188193  92.94193858 101.36779202 109.75307469
#  118.06939786 126.48880314 134.88408908 143.19825192]

# %%
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['nmax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(arr_n[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Radial mode')
plt.show()

# %%
dnus = []
epsilons = []
alphas = []
As = []
Gs = []
phis = []
taus = []
for i in range(len(IDs)):
    dnus.append(np.mean(fit['dnu'],axis=0)[i])
    epsilons.append(np.mean(fit['epsilon'],axis=0)[i])
    alphas.append(np.mean(fit['alpha'],axis=0)[i])
    As.append(np.mean(fit['A'],axis=0)[i])
    Gs.append(np.mean(fit['G'],axis=0)[i])
    phis.append(np.mean(fit['phi'],axis=0)[i])
    taus.append(np.mean(fit['tau'],axis=0)[i])
    
fig, axs = plt.subplots(2, 3, figsize=(15, 8), sharey=False, sharex=False)
axs[0,0].scatter(dnus, epsilons)
axs[0,0].set_title(r'$\epsilon$')
axs[1,0].scatter(dnus, alphas)
axs[1,0].set_title(r'$\alpha$')
axs[0,1].scatter(dnus, As)
axs[0,1].set_title(r'$\mathcal{A}$')
axs[1,1].scatter(dnus, Gs)
axs[1,1].set_title(r'$\mathcal{G}$')
axs[0,2].scatter(dnus, phis)
axs[0,2].set_title(r'$\phi$')
axs[1,2].scatter(dnus, taus)
axs[1,2].set_title(r'$\tau$')
fig.suptitle(r'Parameters plotted against $\langle \Delta \nu \rangle$')
# Out:
# Text(0.5, 0.98, 'Parameters plotted against $\\langle \\Delta \\nu \\rangle$')

# %%
import corner
data = np.vstack([fit['epsilon'], fit['alpha'], fit['dnu'], fit['nmax'],
                  fit['a'], fit['omega'], fit['phi'], fit['tau']]).T
corner.corner(data, labels=[r'$\epsilon$', r'$k$',r'$\Delta\nu$',r'$n_{max}$',
                            r'$A$', r'$\omega$', r'$\phi$', r'$\tau$'])
              #, truths=[1.436, 0.07, 0.3, 2, 0])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-15-ac735519cbd9> in <module>
#       1 import corner
#       2 data = np.vstack([fit['epsilon'], fit['alpha'], fit['dnu'], fit['nmax'],
# ----> 3                   fit['a'], fit['omega'], fit['phi'], fit['tau']]).T
#       4 corner.corner(data, labels=[r'$\epsilon$', r'$k$',r'$\Delta\nu$',r'$n_{max}$',
#       5                             r'$A$', r'$\omega$', r'$\phi$', r'$\tau$'])
#
# stanfit4anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3_6486327874378546150.pyx in stanfit4anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3_6486327874378546150.StanFit4Model.__getitem__()
#
# stanfit4anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3_6486327874378546150.pyx in stanfit4anon_model_ea1f1dcb5b4f091dc3b628af19cb03a3_6486327874378546150.StanFit4Model.extract()
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pystan/misc.py in _check_pars(allpars, pars)
#     807     for par in pars:
#     808         if par not in allpars:
# --> 809             raise ValueError("No parameter {}".format(par))
#     810
#     811
#
# ValueError: No parameter a
