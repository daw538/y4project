# %%
# ORIGINAL RGB FILE
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import random
import pystan
import os
from IPython.display import display
from matplotlib import rc
rc("font", family="serif", size=11)

# %%
#Import output data
output = pd.read_csv('../data/output_back_filesremoved.csv', usecols=[1,11,24])
#IDs = [(output.loc[output['ID'] == random.choice(output['ID'])]).iloc[0]['Numax'] for i in range(5)]

#Set numax range so stars are chosen with similar size echelles
rng = 30
numax_tgt = 75
output = output.loc[(np.abs(output['numax'] - numax_tgt) < rng)].reset_index(drop=True)

#Number of stars to model
nStars = 5

#Selects a random sample of stars from the file, recording their IDs
IDs = [random.choice(output['kic']) for i in range(nStars)]

# Create a list of the numax values and errors corresponding to each ID
Numax = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax'] for i in range(len(IDs))]
Numax_err = [(output.loc[(output['kic'] == IDs[i])]).iloc[0]['numax_err'] for i in range(len(IDs))]

print(IDs)
# Out:
# [9350701, 9080175, 8565016, 5112361, 10162765]

# %%
#Create acyclic graph (probabalistic graphical model)
from matplotlib import rc
rc("font", family="serif", size=16)
import daft
pgm = daft.PGM([3,3], grid_unit=3, node_unit=2)
# Hierarchical parameters.
pgm.add_node(daft.Node("AA", r"$AA_{RGB}$", 1.0, 2.6))
pgm.add_node(daft.Node("AB", r"$AB_{RGB}$", 2.0, 2.6))
# Add latent variables 
pgm.add_node(daft.Node("A_true", r"$A_{{\rm true},i}$", 1.5, 1.7))
# Data.
pgm.add_node(daft.Node("A_obs", r"$A_{{\rm obs},i}$", 1.5, 0.8, observed=True))
pgm.add_node(daft.Node("Aerr", r"$\sigma_{A_{{\rm obs},i}}$", 0.4, 0.8, fixed=True, offset=[0.0,0.4]))
# Add in the edges.
pgm.add_edge("AA", "A_true")
pgm.add_edge("AB", "A_true")
pgm.add_edge("A_obs", "A_true")
pgm.add_edge("Aerr", "A_obs")
# And a plate.
pgm.add_plate(daft.Plate([0.1, 0.4, 2.7, 1.7], label=r"$i = 1, \cdots, N$",
    shift=-0.1))
# Render and save.
pgm.render()

# %%
#Import mode data and construct arrays for storing orders and frequencies
modesID = [pd.read_csv('../data/rgbmodes/modes_'+str(IDs[i])+'.csv', usecols=['f0', 'f0_err', 'A0']) for i in np.arange(0,len(IDs),1)]
lenmodes = [len(modesID[i]) for i in range(len(IDs))]
maxmodes = max(lenmodes)
arr_n = np.zeros([len(IDs),maxmodes])
arr_freq = np.zeros([len(IDs),maxmodes])
arr_freqerr = np.zeros([len(IDs),maxmodes])

#Sort values by frequency and assign order and calculate avg dnu
dnu_avgID = []
for i in np.arange(0,len(IDs),1):
    modesID[i] = modesID[i].sort_values(by=['f0'])
    modesID[i] = modesID[i].set_index(np.arange(0,len(modesID[i]),1))
    modesID[i]['dnu'] = (modesID[i]['f0'].diff(2).shift(-1))/2
    dnu_avg = (np.mean(modesID[i]['dnu']))
    dnu_avgID.append(dnu_avg)
    
    n_min = int(modesID[i]['f0'].min() / dnu_avg)
    n = np.arange(n_min, n_min+len(modesID[i]), 1)
    modesID[i].insert(loc=0, column='n', value=n)
    
    # Loop to ensure all arrays are the same length
    #(due to some stars having fewer mode frequencies observed)
    if lenmodes[i] < maxmodes:
        l = lenmodes[i]
        while l < maxmodes:
            newrow = {'n': int(np.max(modesID[i]['n'])+1),
                      'f0': np.max(modesID[i]['f0'])+dnu_avgID[i],
                      'f0_err': 100000}
            modesID[i] = modesID[i].append(newrow, ignore_index=True)
            #modesID[i].loc[l] = [l, int(np.max(modesID[i]['n']+l)), (np.max(modesID[i]['dnu'])+dnu_avgID[i]), np.nan , 10000]
            #app = pd.DataFrame([(np.max(modesID[i]['dnu'])+dnu_avgID[i]), 10000], columns=['n', 'f0', 'f0_err'])
            #modesID[i].append(app, ignore_index=True)
            l += 1
        
    arr_n[i,:] = modesID[i]['n']
    arr_freq[i,:] = modesID[i]['f0']
    arr_freqerr[i,:] = modesID[i]['f0_err']
    
    #display(modesID[i])
dnu_avgarr = np.asarray(dnu_avgID)

# %%
#Construct and plot echelles for each star
for i in np.arange(0,len(IDs),1):
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], label=r'ID = '+str(IDs[i]))

#Define start parameters
eps = []
for i in range(len(IDs)):
    epsilon1 = np.median((modesID[i].f0 % dnu_avg) / dnu_avg)
    eps.append(epsilon1)
epsilon = np.asarray(eps)

numax_obs = Numax
numax_err = Numax_err
nmax = numax_obs/dnu_avgarr - epsilon
alpha = 0.015*dnu_avgarr**(-0.32)
#A = 0.06*dnu_avgarr**(-0.88) 
A = 0.06*dnu_avgarr**(-0.88)
G = np.ones([len(IDs)])*3.08
tau = np.ones([len(IDs)])*10
phi = np.ones([len(IDs)])*1.71

plt.ylabel('Frequency')
plt.xlabel(r'Frequency modulo')
#plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.show()

# %% [markdown]
# $A_{n_{max}} = A_0 e^{-\frac{n}{\tau}}$
#
# Rearrange for A0 is transformed parameter

# %%
code = '''
functions{
    real asex(real n, real dnu, real nmax, real epsilon, real alpha, real A0, real G, real phi, real tau){
        return (n + epsilon + (alpha/2) * (nmax - n)^2 + 
                A0*G/(2*pi()) * sin((2*pi()*(n-nmax))/G + phi))*dnu
                *exp(-n/tau);
    }
}
data {
    int N;  //number of stars
    int M; //number of modes
    real n[N, M]; //order
    real freq[N, M]; //mode frequency
    real freq_err[N, M]; //uncertainty in mode frequency
    real dnu_guess[N];  //calculated estimate of dnu
    real numax_obs[N];  //calculated numax from data
    real numax_err[N];  //error in numax
}
parameters {
    real dnu[N];
    real<lower = 0> numax[N];
    
    real epsilon_std[N];
    real<lower = 0> eps_sig;
    real epsA;
    real epsB;
    
    real alpha_std[N];
    real<lower = 0> al_sig;
    real alA;
    real alB;
    
    //real A_std[N];
    //real<lower = 0> A_sig;
    real<lower = 0> A[N];
    //real AA;
    //real AB;
    
    real<lower = 0> G[N];
    real<lower = -2.0*pi(), upper = 2.0*pi()> phi[N];
    real<lower = 0> tau[N];
    
}

transformed parameters{
    real epsilon[N];
    real alpha[N];
    //real A[N];
    for (i in 1:N){
        epsilon[i] = epsilon_std[i] * eps_sig + (epsA + epsB * log(dnu[i]));
        alpha[i] = alpha_std[i] * al_sig + (alA * (dnu[i])^(-alB));
        //A[i] = A_std[i] * A_sig + (AA*dnu[i]^(-AB));
    }
}
model {
    real mod[M];
    real nmax[N];
    real A0[N];
    //real A[N];
    for (i in 1:N){
        nmax[i] = numax[i]/dnu[i] - epsilon[i];
        A0[i] = A[i]*exp(nmax[i]/tau[i]);
        for (j in 1:M){
            mod[j] = asex(n[i,j], dnu[i], nmax[i], epsilon[i], alpha[i], A0[i], G[i], phi[i], tau[i]);
            //mod[j] ~ normal(freq[i], freq_err[i]);
        }
        freq[i,:] ~ normal(mod, freq_err[i,:]);
        numax[i] ~ normal(numax_obs[i], numax_err[i]);
        dnu[i] ~ normal(dnu_guess[i], dnu_guess[i]*0.01);
        //epsilon[i] ~ normal(epsA + epsB*log(dnu[i]), 0.5);
        //alpha[i] ~ lognormal(log(alA*dnu[i]^(-alB)), 0.3);
        //A0[i] ~ lognormal(log(AA*dnu[i]^(-AB)), 0.4);
        A[i] ~ lognormal(log(A0[i]*exp(nmax[i]/tau[i])), 0.4);
        //A[i] ~ normal(0.01, 0.4);
        //epsilon[i] ~ uniform(-1.0, 2.0);
        //alpha[i] ~ lognormal(log(0.015*dnu[i]^(-0.32)), 0.5);
        A0[i] ~ lognormal(log(0.06*dnu[i]^(-0.88)), 0.6);
    }
    nmax ~ normal(10, 4);
    G ~ normal(3.08, 0.65);
    tau ~ normal(30, 10);
    epsilon_std ~ normal(0, 1);
    eps_sig ~ normal(0, 0.5);
    epsA ~ normal(0.601, 0.08);
    epsB ~ normal(0.632, 0.08);
    alpha_std ~ normal(0, 1);
    al_sig ~ normal(0, 0.5); 
    alA ~ normal(0.015, 0.005);
    alB ~ normal(0.32, 0.08);
    //A_std ~ normal(0, 1);
    //A_sig ~ normal(0, 0.5);
    //AA ~ normal(0.06, 0.01);
    //AB ~ normal(0.88, 0.05);
}
'''
sm = pystan.StanModel(model_code=code)
# Out:
# INFO:pystan:COMPILING THE C++ CODE FOR MODEL anon_model_82d8dc35eeb8bb1c15232ad37ec070eb NOW.
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/Cython/Compiler/Main.py:367: FutureWarning: Cython directive 'language_level' not set, using 2 for now (Py2). This will change in a later release! File: /var/folders/2_/b8v0t8pn1hj1p3r4lyfvvv2h0000gn/T/tmpj8wmdh67/stanfit4anon_model_82d8dc35eeb8bb1c15232ad37ec070eb_1431120165851861176.pyx
#   tree = Parsing.p_module(s, pxd, full_module_name)

# %%
stan_data = {'N': len(IDs),
         'M': maxmodes,
         'n': arr_n, 
         'freq': arr_freq,
         'freq_err': arr_freqerr,
         'dnu_guess': dnu_avgarr,
         'numax_obs': numax_obs,
         'numax_err': numax_err
        }
start = {'dnu': dnu_avgarr,
         'nmax': nmax,
         'numax': numax_obs,
         #'epsilon': epsilon,
         #'alpha': alpha,
         'A0': A,
         'A': 0.0001*np.ones([len(IDs)]),
         'eps_sig': 0.01,
         'al_sig': 0.01,
         'A_sig': 0.01,
         'G': G,
         'tau': tau,
         'phi': phi,
         'epsA': 0.601,
         'epsB': 0.632,
         'alA': 0.015,
         'alB': 0.32,
         'AA': 0.06,
         'AB': 0.88
        }
nchains = 4

fit = sm.sampling(data=stan_data, iter=5000, chains=nchains, init=[start for n in range(nchains)])
# Out:
# WARNING:pystan:n_eff / iter for parameter dnu[2] is 0.00044741587309968044!
# WARNING:pystan:n_eff / iter for parameter dnu[5] is 0.0009300405544328862!
# WARNING:pystan:n_eff / iter for parameter numax[1] is 0.0002148040727686324!
# WARNING:pystan:n_eff / iter for parameter numax[2] is 0.0004512570244597365!
# WARNING:pystan:n_eff / iter for parameter numax[4] is 0.00028522158690618505!
# WARNING:pystan:n_eff / iter for parameter numax[5] is 0.000898208038221606!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[2] is 0.0005614575787113043!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[4] is 0.0008557609192706394!
# WARNING:pystan:n_eff / iter for parameter epsilon_std[5] is 0.0008084273123996559!
# WARNING:pystan:n_eff / iter for parameter epsB is 0.0009645585312867139!
# WARNING:pystan:n_eff / iter for parameter alpha_std[1] is 0.0003100901080125042!
# WARNING:pystan:n_eff / iter for parameter alpha_std[2] is 0.00032608650576075837!
# WARNING:pystan:n_eff / iter for parameter alpha_std[3] is 0.00026388372017094975!
# WARNING:pystan:n_eff / iter for parameter alpha_std[4] is 0.0002754781700674019!
# WARNING:pystan:n_eff / iter for parameter alpha_std[5] is 0.00024668854274931354!
# WARNING:pystan:n_eff / iter for parameter al_sig is 0.00031758565680053307!
# WARNING:pystan:n_eff / iter for parameter A[1] is 0.00020516708806068008!
# WARNING:pystan:n_eff / iter for parameter A[2] is 0.0003356463947322525!
# WARNING:pystan:n_eff / iter for parameter A[3] is 0.00027557755279540553!
# WARNING:pystan:n_eff / iter for parameter A[4] is 0.0002251778708867682!
# WARNING:pystan:n_eff / iter for parameter A[5] is 0.000223694410926289!
# WARNING:pystan:n_eff / iter for parameter G[1] is 0.00020416993517921852!
# WARNING:pystan:n_eff / iter for parameter G[2] is 0.00028220534287769846!
# WARNING:pystan:n_eff / iter for parameter G[3] is 0.00022298279346423698!
# WARNING:pystan:n_eff / iter for parameter G[4] is 0.00022125154144764578!
# WARNING:pystan:n_eff / iter for parameter G[5] is 0.0002466579469750076!
# WARNING:pystan:n_eff / iter for parameter phi[1] is 0.00021201640168721472!
# WARNING:pystan:n_eff / iter for parameter phi[2] is 0.00027858743516826206!
# WARNING:pystan:n_eff / iter for parameter phi[3] is 0.00047549287811401406!
# WARNING:pystan:n_eff / iter for parameter phi[4] is 0.00022864266934336473!
# WARNING:pystan:n_eff / iter for parameter phi[5] is 0.0002461369406574544!
# WARNING:pystan:n_eff / iter for parameter tau[1] is 0.00026799738309944156!
# WARNING:pystan:n_eff / iter for parameter tau[3] is 0.0003212751335014592!
# WARNING:pystan:n_eff / iter for parameter tau[4] is 0.000544309369420349!
# WARNING:pystan:n_eff / iter for parameter tau[5] is 0.0004387010520057289!
# WARNING:pystan:n_eff / iter for parameter epsilon[1] is 0.00038617279309151564!
# WARNING:pystan:n_eff / iter for parameter epsilon[2] is 0.00047649701515064223!
# WARNING:pystan:n_eff / iter for parameter epsilon[5] is 0.0007989224647884126!
# WARNING:pystan:n_eff / iter for parameter alpha[1] is 0.00025282496361726185!
# WARNING:pystan:n_eff / iter for parameter alpha[2] is 0.00037674930122037634!
# WARNING:pystan:n_eff / iter for parameter alpha[4] is 0.0006515657309358651!
# WARNING:pystan:n_eff / iter for parameter alpha[5] is 0.0006090513015053795!
# WARNING:pystan:n_eff / iter for parameter lp__ is 0.00026563567573192496!
# WARNING:pystan:n_eff / iter below 0.001 indicates that the effective sample size has likely been overestimated
# WARNING:pystan:Rhat for parameter dnu[1] is 1.5134120305347054!
# WARNING:pystan:Rhat for parameter dnu[2] is 1.7891240809372269!
# WARNING:pystan:Rhat for parameter dnu[3] is 1.4772862896168566!
# WARNING:pystan:Rhat for parameter dnu[4] is 1.7164674539260183!
# WARNING:pystan:Rhat for parameter dnu[5] is 1.7291609159293977!
# WARNING:pystan:Rhat for parameter numax[1] is 4.64384996408956!
# WARNING:pystan:Rhat for parameter numax[2] is 1.9233491532145754!
# WARNING:pystan:Rhat for parameter numax[3] is 1.6813451415933538!
# WARNING:pystan:Rhat for parameter numax[4] is 2.159307427108136!
# WARNING:pystan:Rhat for parameter numax[5] is 1.5618531264664268!
# WARNING:pystan:Rhat for parameter epsilon_std[1] is 1.7552427820954153!
# WARNING:pystan:Rhat for parameter epsilon_std[2] is 2.323703512908307!
# WARNING:pystan:Rhat for parameter epsilon_std[3] is 1.7646870775783232!
# WARNING:pystan:Rhat for parameter epsilon_std[4] is 1.9147032576939045!
# WARNING:pystan:Rhat for parameter epsilon_std[5] is 2.048713922189467!
# WARNING:pystan:Rhat for parameter eps_sig is 1.496466279799476!
# WARNING:pystan:Rhat for parameter epsA is 1.6083602410720101!
# WARNING:pystan:Rhat for parameter epsB is 1.7517890057400232!
# WARNING:pystan:Rhat for parameter alpha_std[1] is 1.9087269587207023!
# WARNING:pystan:Rhat for parameter alpha_std[2] is 2.031933951764669!
# WARNING:pystan:Rhat for parameter alpha_std[3] is 2.3747745370486855!
# WARNING:pystan:Rhat for parameter alpha_std[4] is 2.1946986470262764!
# WARNING:pystan:Rhat for parameter alpha_std[5] is 2.540551489847524!
# WARNING:pystan:Rhat for parameter al_sig is 2.0421397838126323!
# WARNING:pystan:Rhat for parameter A[1] is 7.9952680554871!
# WARNING:pystan:Rhat for parameter A[2] is 2.109395613412282!
# WARNING:pystan:Rhat for parameter A[3] is 2.731042557840479!
# WARNING:pystan:Rhat for parameter A[4] is 3.3174478301419414!
# WARNING:pystan:Rhat for parameter A[5] is 3.227548617171871!
# WARNING:pystan:Rhat for parameter G[1] is 8.977538884889599!
# WARNING:pystan:Rhat for parameter G[2] is 2.4620680465299682!
# WARNING:pystan:Rhat for parameter G[3] is 6.218999525426421!
# WARNING:pystan:Rhat for parameter G[4] is 3.8134115273782063!
# WARNING:pystan:Rhat for parameter G[5] is 2.7856380649465873!
# WARNING:pystan:Rhat for parameter phi[1] is 4.729867706692937!
# WARNING:pystan:Rhat for parameter phi[2] is 2.2318697090013773!
# WARNING:pystan:Rhat for parameter phi[3] is 2.395409948173982!
# WARNING:pystan:Rhat for parameter phi[4] is 2.9370818840041024!
# WARNING:pystan:Rhat for parameter phi[5] is 2.8578367564087777!
# WARNING:pystan:Rhat for parameter tau[1] is 2.699655419305122!
# WARNING:pystan:Rhat for parameter tau[2] is 1.4326695926147286!
# WARNING:pystan:Rhat for parameter tau[3] is 1.797588662644869!
# WARNING:pystan:Rhat for parameter tau[4] is 1.4889349814338555!
# WARNING:pystan:Rhat for parameter tau[5] is 1.7387975893005208!
# WARNING:pystan:Rhat for parameter epsilon[1] is 2.354377324191435!
# WARNING:pystan:Rhat for parameter epsilon[2] is 1.7758215804098278!
# WARNING:pystan:Rhat for parameter epsilon[3] is 1.5867204062358673!
# WARNING:pystan:Rhat for parameter epsilon[4] is 1.715386448363539!
# WARNING:pystan:Rhat for parameter epsilon[5] is 1.8173482717585383!
# WARNING:pystan:Rhat for parameter alpha[1] is 3.410482258808231!
# WARNING:pystan:Rhat for parameter alpha[2] is 1.9300227474904068!
# WARNING:pystan:Rhat for parameter alpha[3] is 1.6363260279449814!
# WARNING:pystan:Rhat for parameter alpha[4] is 1.7143857568495389!
# WARNING:pystan:Rhat for parameter alpha[5] is 1.84011297827322!
# WARNING:pystan:Rhat for parameter lp__ is 3.6701947624658406!
# WARNING:pystan:Rhat above 1.1 or below 0.9 indicates that the chains very likely have not mixed
# WARNING:pystan:3217 of 10000 iterations ended with a divergence (32.17%).
# WARNING:pystan:Try running with adapt_delta larger than 0.8 to remove the divergences.
# WARNING:pystan:6783 of 10000 iterations saturated the maximum tree depth of 10 (67.83%)
# WARNING:pystan:Run again with max_treedepth larger than 10 to avoid saturation
# WARNING:pystan:Chain 1: E-BFMI = 0.0011037883046461359
# WARNING:pystan:Chain 2: E-BFMI = 0.003677932551271769
# WARNING:pystan:Chain 3: E-BFMI = 0.0006521357849765122
# WARNING:pystan:Chain 4: E-BFMI = 0.0010357469682575578
# WARNING:pystan:E-BFMI below 0.2 indicates you may need to reparameterize your model

# %%
print(fit)
# Out:
# Inference for Stan model: anon_model_82d8dc35eeb8bb1c15232ad37ec070eb.
# 4 chains, each with iter=5000; warmup=2500; thin=1;
# post-warmup draws per chain=2500, total post-warmup draws=10000.
#
#                  mean se_mean     sd   2.5%    25%    50%    75%  97.5%  n_eff   Rhat
# dnu[1]           5.78    0.03   0.09   5.56   5.74    5.8   5.83   5.93     12   1.51
# dnu[2]           5.43    0.05   0.11   5.29   5.36   5.41   5.47   5.73      4   1.79
# dnu[3]           6.13    0.02   0.07   5.98   6.08   6.13   6.19   6.25     13   1.48
# dnu[4]           6.34    0.04   0.12   6.13   6.23   6.37   6.43   6.52     11   1.72
# dnu[5]           6.94    0.05   0.15   6.72    6.8   6.91   7.09   7.19      9   1.73
# numax[1]        57.68    1.25   1.83  54.62  55.99   57.8  59.32  60.06      2   4.64
# numax[2]        48.07    0.27   0.58  46.77  48.06  48.27  48.44  48.69      5   1.92
# numax[3]        60.94    0.15   0.51  59.81  60.69   61.0   61.3  61.82     12   1.68
# numax[4]        68.72    0.66   1.11  66.96  67.75  68.67  69.66  70.59      3   2.16
# numax[5]        83.62    0.64   1.92  80.16  81.97   83.7  85.25  86.72      9   1.56
# epsilon_std[1]   1.42    0.34    1.1  -0.97    0.7   1.53   1.92   3.49     10   1.76
# epsilon_std[2]   0.66    0.54   1.27  -1.56  -0.21   0.81   1.57   2.92      6   2.32
# epsilon_std[3]   1.57    0.26   0.88  -0.38   1.09   1.54   2.01   3.37     11   1.76
# epsilon_std[4]   1.38    0.41    1.2  -1.15   0.74    1.6   2.05   3.68      9   1.91
# epsilon_std[5]   1.91    0.49    1.4  -0.97   1.01    2.0   2.95   4.41      8   2.05
# eps_sig          0.74    0.22   0.75 4.7e-3   0.02   0.83   1.13   2.74     11    1.5
# epsA             1.11    0.08   0.27   0.64   0.86   1.11   1.36   1.49     11   1.61
# epsB             1.55    0.16   0.48   0.77   1.12   1.64   2.04   2.13     10   1.75
# alpha_std[1]     1.31    0.21   0.38   0.71   0.97   1.31   1.65   1.98      3   1.91
# alpha_std[2]     1.65    0.27   0.49   0.96   1.23   1.54   2.09   2.54      3   2.03
# alpha_std[3]     1.29    0.26   0.42   0.73   0.94   1.17   1.61   2.09      3   2.37
# alpha_std[4]     0.96    0.18    0.3   0.58    0.7   0.88   1.21   1.54      3   2.19
# alpha_std[5]     0.85     0.2   0.32   0.47   0.59   0.75   1.02   1.51      2   2.54
# al_sig           0.76    0.13   0.23   0.43   0.55   0.76   0.96   1.22      3   2.04
# alA              0.02  4.8e-4 5.3e-3 5.9e-3   0.01   0.02   0.02   0.03    123   1.03
# alB              0.31  6.3e-3   0.08   0.17   0.26   0.31   0.36   0.46    145   1.04
# A[1]             0.15    0.06   0.09 1.9e-4   0.05   0.19   0.22   0.24      2    8.0
# A[2]             0.14    0.04   0.07 3.2e-4   0.12   0.16   0.18    0.2      3   2.11
# A[3]             0.14    0.04   0.07 3.8e-4    0.1   0.12    0.2   0.24      3   2.73
# A[4]             0.07    0.03   0.04 1.7e-4 7.0e-4   0.07    0.1   0.11      2   3.32
# A[5]             0.02    0.01   0.02 2.4e-4 1.0e-3 3.7e-3   0.04   0.06      2   3.23
# G[1]             5.46    1.67   2.38   2.78   3.02   4.64   7.84   8.31      2   8.98
# G[2]             5.51    0.84   1.41   1.83    4.6   6.11   6.44   7.03      3   2.46
# G[3]             3.83    1.07   1.59    2.3   2.36   2.79   5.64   6.19      2   6.22
# G[4]              5.2    1.16   1.73   2.44   3.95   4.19   6.89   7.44      2   3.81
# G[5]             3.62    0.55   0.87   2.24   2.74    3.6    4.5   4.78      2   2.79
# phi[1]           2.67    1.69   2.47  -0.69   0.23   3.54   5.11   5.34      2   4.73
# phi[2]           4.07     0.8   1.34   1.37   3.25   4.75   4.94   5.27      3   2.23
# phi[3]           3.49    0.38   0.83    0.8   3.47   3.77   3.93   4.22      5    2.4
# phi[4]            3.6    1.26   1.91   0.36   2.68   3.59   5.41   6.28      2   2.94
# phi[5]           2.13    2.48   3.89  -5.85  -1.17   3.23   5.82   6.13      2   2.86
# tau[1]           9.78     0.2   0.33   9.21   9.43   9.95  10.08  10.19      3    2.7
# tau[2]           8.08    0.05   0.15    7.8   7.95    8.1   8.17   8.41     11   1.43
# tau[3]           9.73    0.08   0.14   9.53   9.61   9.71   9.82  10.04      3    1.8
# tau[4]          11.99    0.08   0.19  11.59  11.89  12.02  12.11   12.3      5   1.49
# tau[5]          13.54    0.21   0.45  12.82  13.17  13.52  13.88   14.4      4   1.74
# epsilon[1]       5.11    0.16   0.31   4.64   4.89   5.06   5.36   5.74      4   2.35
# epsilon[2]       4.72     0.1   0.22   4.14   4.57   4.78   4.87   5.02      5   1.78
# epsilon[3]       5.27    0.04   0.15   5.05   5.15   5.24   5.37   5.59     12   1.59
# epsilon[4]       5.42    0.08   0.26   5.12   5.22   5.31   5.67    6.0     12   1.72
# epsilon[5]       6.01    0.18    0.5   5.31   5.47   6.14    6.5    6.7      8   1.82
# alpha[1]         0.92    0.06    0.1   0.81   0.84   0.89   1.02   1.09      3   3.41
# alpha[2]         1.16    0.03   0.07   1.05    1.1   1.17   1.22   1.26      4   1.93
# alpha[3]          0.9  7.7e-3   0.03   0.85   0.88    0.9   0.92   0.94     11   1.64
# alpha[4]         0.68    0.01   0.03   0.63   0.65   0.67   0.69   0.75      7   1.71
# alpha[5]         0.59    0.02   0.05   0.51   0.54    0.6   0.63   0.66      6   1.84
# lp__           -942.9  306.65 499.79  -1936  -1324 -774.7 -553.4 -344.8      3   3.67
#
# Samples were drawn using NUTS at Fri Feb  8 18:33:34 2019.
# For each parameter, n_eff is a crude measure of effective sample size,
# and Rhat is the potential scale reduction factor on split chains (at
# convergence, Rhat=1).

# %%
fit.plot()
plt.show()
# Out:
# WARNING:pystan:Deprecation warning. In future, use ArviZ library (`pip install arviz`)

# %%
def model(n, dnu, numax, epsilon, alpha, A, G, phi, tau):
    nmax = numax/dnu - epsilon
    freqs = (n + epsilon + (alpha/2) * (n - nmax)**2 + ((A*G)/(2*np.pi)) * np.sin((2*np.pi*(n-nmax))/G + phi)) * dnu# * np.exp(-n/tau)
    return freqs

# %%
#for i in range(len(IDs)):
    #print(np.mean(modesID[i]['dnu']))

#for i in range(len(IDs)):
    #print(np.mean(fit['G'], axis=0)[i])

# %%
# %matplotlib inline

#Plot stan fitted model on echelle
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['f0'] % dnu_avgID[i], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(g2 % np.mean(fit['dnu'],axis=0)[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Mod. Freq. Spacing ($\mu Hz$)')
plt.xlim(-2,7)
plt.show()

# %%
#Plot stan fitted model for freq vs n
for i in range(len(IDs)):
    plt.figure(len(IDs))
    plt.scatter(modesID[i]['n'], modesID[i]['f0'], marker='x', label=r'$l=$'+str(0))
    #plt.errorbar(modesID[i]['f0'] % np.mean(modesID[i]['dnu']), modesID[i]['f0'], xerr=modesID[i]['f0_err'], zorder=0, fmt="none", label="none",
             #c='k', capsize=2, markersize=4, elinewidth=1)
    #np.mean(modesID[i]['dnu'])
    g2 = model(arr_n[i], np.mean(fit['dnu'],axis=0)[i], np.mean(fit['numax'],axis=0)[i], np.mean(fit['epsilon'], axis=0)[i], np.mean(fit['alpha'], axis=0)[i],
          np.mean(fit['A'], axis=0)[i], np.mean(fit['G'], axis=0)[i], np.mean(fit['phi'], axis=0)[i], 33) #np.mean(fit['tau'], axis=0)[i])
    plt.plot(arr_n[i], g2, label='Fit_2D')

plt.ylabel('Frequency ($\mu Hz$)')
plt.xlabel(f'Radial mode')
plt.show()

# %%
#Plot stan deduced parameters against dnu
dnus = []
numaxs = []
epsilons = []
alphas = []
As = []
Gs = []
phis = []
taus = []
for i in range(len(IDs)):
    dnus.append(np.mean(fit['dnu'],axis=0)[i])
    numaxs.append(np.mean(fit['dnu'],axis=0)[i])
    epsilons.append(np.mean(fit['epsilon'],axis=0)[i])
    alphas.append(np.mean(fit['alpha'],axis=0)[i])
    As.append(np.mean(fit['A'],axis=0)[i])
    Gs.append(np.mean(fit['G'],axis=0)[i])
    phis.append(np.mean(fit['phi'],axis=0)[i])
    taus.append(np.mean(fit['tau'],axis=0)[i])
    
fig, axs = plt.subplots(2, 3, figsize=(15, 8), sharey=False, sharex=False)
axs[0,0].scatter(dnus, epsilons)
axs[0,0].set_title(r'$\epsilon$')
axs[1,0].scatter(dnus, alphas)
axs[1,0].set_title(r'$\alpha$')
axs[0,1].scatter(dnus, As)
axs[0,1].set_title(r'$\mathcal{A}$')
axs[1,1].scatter(dnus, Gs)
axs[1,1].set_title(r'$\mathcal{G}$')
axs[0,2].scatter(dnus, phis)
axs[0,2].set_title(r'$\phi$')
axs[1,2].scatter(dnus, taus)
axs[1,2].set_title(r'$\tau$')
fig.suptitle(r'Parameters plotted against $\langle \Delta \nu \rangle$')
# Out:
# Text(0.5, 0.98, 'Parameters plotted against $\\langle \\Delta \\nu \\rangle$')

# %%
plt.scatter(numaxs, Gs)
plt.xlabel(r'$\nu_{max} (\mu Hz)$')
plt.ylabel(r'$\mathcal{G}$ ($\mu Hz$)')
plt.title(r'Period vs frequency of max power ($\nu_{max}$)')
# Out:
# Text(0.5, 1.0, 'Period vs frequency of max power ($\\nu_{max}$)')

# %%
#Plot glitch amplitude against metallicity from APOKASC catalogue
df_met = pd.read_csv('../data/APOKASCfull.csv')
#metals = [(df_met.loc[(df_met['KIC'] == IDs[i])]).loc['[M/H]2'] for i in range(len(IDs))]


#metals = df_met.loc[(df_met['KIC'].isin(IDs))].reset_index(drop=True)

frames = []
for i in range(len(IDs)):
    mets = df_met.loc[df_met['KIC'] == IDs[i]]
    frames.append(mets)

metsall = pd.concat(frames).reset_index(drop=True)

IDdf = pd.DataFrame(IDs)
#ind = IDdf[~IDdf.isin(metsall['KIC'])]

#print(ind)
#print(metsall['KIC'])
#print(IDs)

plt.scatter(metsall['[M/H]2'].values, As)
#plt.xlabel('Metallicity')
#plt.ylabel('Glitch amplitude ($\mu Hz$)')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-7e785997d3e0> in <module>
#      20 #print(IDs)
#      21
# ---> 22 plt.scatter(metsall['[M/H]2'].values, As)
#      23 #plt.xlabel('Metallicity')
#      24 #plt.ylabel('Glitch amplitude ($\mu Hz$)')
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, data, **kwargs)
#    2791         x=x, y=y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2792         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
# -> 2793         verts=verts, edgecolors=edgecolors, data=data, **kwargs)
#    2794     sci(__ret)
#    2795     return __ret
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1783                         "the Matplotlib list!)" % (label_namer, func.__name__),
#    1784                         RuntimeWarning, stacklevel=2)
# -> 1785             return func(ax, *args, **kwargs)
#    1786
#    1787         inner.__doc__ = _add_data_doc(inner.__doc__,
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/matplotlib/axes/_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, **kwargs)
#    4163         y = np.ma.ravel(y)
#    4164         if x.size != y.size:
# -> 4165             raise ValueError("x and y must be the same size")
#    4166
#    4167         if s is None:
#
# ValueError: x and y must be the same size
